# %% [markdown]
# ---
# # FMPClient Experimentation
# ---
# Notebook: 0.0.2-iw-fmpclient-experimentation.ipynb<br>
# Dependencies: requirements.txt<br>
# Date: 2019-OCT-2<br>
# Abstract:
# ```
#     The goal of this notebook is to work towards library code which will ingest the necessary financial data for our modelling. In particular we will excersize the FMPClient library and make API calls to the FinancialModellingPrep library; and see what data we can get back.
# ```

# %% [markdown]
# ---
# ## 0. Setup
# ---

# %%
import pandas as pd
import json
import fmpclient
from fmpclient import FMPClient
api = FMPClient()
fmpclient.__version__
# Out:
# '0.1.3'

# %% [markdown]
# ---
# ## 1. Fetch Data
# ---
# We want to fetch these metrics for the last five years - calculated annually:
# 1. The Rule of 72 - how long will it take for an investment to double based on compounding interest
# 2. P/E Ratio
# 3. P/B Ratio
# 4. P/S Ratio
# 5. Divident Yield %
# 6. Payout Ratio %
# 7. P/C
# 8. Earnings Growth
# 9. Debt to Equity Ratio

# %% [markdown]
# __1. The Rule of 72 - how long will it take for an investment to double based on compounding interest__

# %%
def compute_double_period(interest_rate):
    """ Compute the period in years it will take to double an investment with the given investment rate """
    return 72.0/interest_rate

# %%
interest_rate = 10
print(f'It will take {compute_double_period(interest_rate)} years to double an investment with an interest rate of {interest_rate}.')
# Out:
# It will take 7.2 years to double an investment with an interest rate of 10.

# %% [markdown]
# __2. P/E Ratio__

# %%
# P/E = Price/Earnings
# balance sheet - consolidated statement of earnings (in 10-k doc)
#               - diluted number for shares outstanding
# income sheet - net income

# stock price * diluted # of shares outstanding /earnings

tickers=['BMO']
res = api.company_valuation.income_statement(tickers, datatype=None)
# Out:
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financials/income-statement/BMO, path: financials/income-statement/BMO

# %%
res
# Out:
# {'symbol': 'BMO',
#  'financials': [{'date': '2018-10-31',
#    'Revenue': '17585496183.2061',
#    'Revenue Growth': '0.0183',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '17585496183.2061',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '8739694656.4885',
#    'Operating Expenses': '11423664122.1374',
#    'Operating Income': '6161832061.0687',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '5656488549.6183',
#    'Income Tax Expense': '1496183206.1069',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '4160305343.5115',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '4160305343.5115',
#    'EPS': '6.2519',
#    'EPS Diluted': '6.2366',
#    'Weighted Average Shs Out': '606119326.7176',
#    'Weighted Average Shs Out (Dil)': '606119326.7176',
#    'Dividend per Share': '2.2466',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.2832',
#    'EBIT Margin': '0.3217',
#    'Profit Margin': '0.1809',
#    'Free Cash Flow margin': '0.7391',
#    'EBITDA': '6516793893.1298',
#    'EBIT': '5656488549.6183',
#    'Consolidated Income': '4160305343.5115',
#    'Earnings Before Tax Margin': '0.3217',
#    'Net Profit Margin': '0.2366'},
#   {'date': '2017-10-31',
#    'Revenue': '17269200930.9542',
#    'Revenue Growth': '0.099',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '17269200930.9542',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '8699767261.443',
#    'Operating Expenses': '11534522885.9581',
#    'Operating Income': '5734678044.9961',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '5154383242.8239',
#    'Income Tax Expense': '1005430566.3305',
#    'Net Income - Non-Controlling int': '1551590.3801',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '4148952676.4934',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '4148952676.4934',
#    'EPS': '6.1676',
#    'EPS Diluted': '6.1443',
#    'Weighted Average Shs Out': '594229117.9209',
#    'Weighted Average Shs Out (Dil)': '594229117.9209',
#    'Dividend per Share': '2.1226',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.27',
#    'EBIT Margin': '0.2985',
#    'Profit Margin': '0.1862',
#    'Free Cash Flow margin': '0.0951',
#    'EBITDA': '6010085337.4709',
#    'EBIT': '5154383242.8239',
#    'Consolidated Income': '4150504266.8735',
#    'Earnings Before Tax Margin': '0.2985',
#    'Net Profit Margin': '0.2403'},
#   {'date': '2016-10-31',
#    'Revenue': '15713114754.0984',
#    'Revenue Growth': '0.0608',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '15713114754.0984',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '8154992548.4352',
#    'Operating Expenses': '10867362146.0507',
#    'Operating Income': '4845752608.0477',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '4264530551.4158',
#    'Income Tax Expense': '820417287.6304',
#    'Net Income - Non-Controlling int': '6706408.3458',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '3444113263.7854',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '3444113263.7854',
#    'EPS': '5.1714',
#    'EPS Diluted': '5.1565',
#    'Weighted Average Shs Out': '550509195.9762',
#    'Weighted Average Shs Out (Dil)': '550509195.9762',
#    'Dividend per Share': '1.9031',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.2392',
#    'EBIT Margin': '0.2714',
#    'Profit Margin': '0.1632',
#    'Free Cash Flow margin': '-0.1583',
#    'EBITDA': '5044709388.9717',
#    'EBIT': '4264530551.4158',
#    'Consolidated Income': '3450819672.1311',
#    'Earnings Before Tax Margin': '0.2714',
#    'Net Profit Margin': '0.2192'},
#   {'date': '2015-10-31',
#    'Revenue': '14812070282.6585',
#    'Revenue Growth': '-0.0856',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '14812070282.6585',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '7958747135.2177',
#    'Operating Expenses': '10264323911.3827',
#    'Operating Income': '4547746371.2758',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '4053475935.8289',
#    'Income Tax Expense': '715049656.2261',
#    'Net Income - Non-Controlling int': '26737967.9144',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '3338426279.6028',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '3338426279.6028',
#    'EPS': '5.0344',
#    'EPS Diluted': '5.0191',
#    'Weighted Average Shs Out': '577333800.6112',
#    'Weighted Average Shs Out (Dil)': '577333800.6112',
#    'Dividend per Share': '1.9542',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.2399',
#    'EBIT Margin': '0.2737',
#    'Profit Margin': '0.1719',
#    'Free Cash Flow margin': '0.089',
#    'EBITDA': '4655462184.8739',
#    'EBIT': '4053475935.8289',
#    'Consolidated Income': '3365164247.5172',
#    'Earnings Before Tax Margin': '0.2737',
#    'Net Profit Margin': '0.2254'},
#   {'date': '2014-10-31',
#    'Revenue': '16198222222.2222',
#    'Revenue Growth': '0.0048',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '16198222222.2222',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '8279111111.1111',
#    'Operating Expenses': '11045333333.3333',
#    'Operating Income': '5152888888.8889',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '4604444444.4444',
#    'Income Tax Expense': '802666666.6667',
#    'Net Income - Non-Controlling int': '49777777.7778',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '3801777777.7778',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '3801777777.7778',
#    'EPS': '5.7244',
#    'EPS Diluted': '5.6978',
#    'Weighted Average Shs Out': '644204395.5556',
#    'Weighted Average Shs Out (Dil)': '644204395.5556',
#    'Dividend per Share': '2.4791',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.2889',
#    'EBIT Margin': '0.2843',
#    'Profit Margin': '0.2089',
#    'Free Cash Flow margin': '-0.2011',
#    'EBITDA': '5268444444.4444',
#    'EBIT': '4604444444.4444',
#    'Consolidated Income': '3851555555.5556',
#    'Earnings Before Tax Margin': '0.2843',
#    'Net Profit Margin': '0.2347'},
#   {'date': '2013-10-31',
#    'Revenue': '16120689655.1724',
#    'Revenue Growth': '0.012',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '16120689655.1724',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '8348659003.8314',
#    'Operating Expenses': '10529693486.59',
#    'Operating Income': '5590996168.5824',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '4966475095.7854',
#    'Income Tax Expense': '1010536398.4674',
#    'Net Income - Non-Controlling int': '62260536.3985',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '3955938697.318',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '3955938697.318',
#    'EPS': '5.9291',
#    'EPS Diluted': '5.91',
#    'Weighted Average Shs Out': '708170157.0881',
#    'Weighted Average Shs Out (Dil)': '708170157.0881',
#    'Dividend per Share': '2.7481',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.3343',
#    'EBIT Margin': '0.3081',
#    'Profit Margin': '0.2347',
#    'Free Cash Flow margin': '0.6434',
#    'EBITDA': '5631226053.6398',
#    'EBIT': '4966475095.7854',
#    'Consolidated Income': '4018199233.7165',
#    'Earnings Before Tax Margin': '0.3081',
#    'Net Profit Margin': '0.2454'},
#   {'date': '2012-10-31',
#    'Revenue': '15929000000.0',
#    'Revenue Growth': '0.1379',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '15929000000.0',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '8572000000.0',
#    'Operating Expenses': '10135000000.0',
#    'Operating Income': '5794000000.0',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '4956000000.0',
#    'Income Tax Expense': '874000000.0',
#    'Net Income - Non-Controlling int': '74000000.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '4082000000.0',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '4082000000.0',
#    'EPS': '6.13',
#    'EPS Diluted': '6.1',
#    'Weighted Average Shs Out': '739599563.0',
#    'Weighted Average Shs Out (Dil)': '739599563.0',
#    'Dividend per Share': '2.831',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.354',
#    'EBIT Margin': '0.3111',
#    'Profit Margin': '0.256',
#    'Free Cash Flow margin': '0.6025',
#    'EBITDA': '5638000000.0',
#    'EBIT': '4956000000.0',
#    'Consolidated Income': '4156000000.0',
#    'Earnings Before Tax Margin': '0.3111',
#    'Net Profit Margin': '0.2563'},
#   {'date': '2011-10-31',
#    'Revenue': '13998995983.9357',
#    'Revenue Growth': '0.2794',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '13998995983.9357',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '7440763052.2088',
#    'Operating Expenses': '8776104417.6707',
#    'Operating Income': '5222891566.2651',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '3932730923.6948',
#    'Income Tax Expense': '879518072.2892',
#    'Net Income - Non-Controlling int': '73293172.6908',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '3053212851.4056',
#    'Preferred Dividends': '0.0',
#    'Net Income Com': '3053212851.4056',
#    'EPS': '4.9197',
#    'EPS Diluted': '4.8594',
#    'Weighted Average Shs Out': '658100843.3735',
#    'Weighted Average Shs Out (Dil)': '593627510.0402',
#    'Dividend per Share': '3.5813',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.3213',
#    'EBIT Margin': '0.2809',
#    'Profit Margin': '0.2189',
#    'Free Cash Flow margin': '0.0701',
#    'EBITDA': '4472891566.2651',
#    'EBIT': '3932730923.6948',
#    'Consolidated Income': '3126506024.0964',
#    'Earnings Before Tax Margin': '0.2809',
#    'Net Profit Margin': '0.2181'},
#   {'date': '2010-10-31',
#    'Revenue': '10942156862.7451',
#    'Revenue Growth': '0.2479',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '10942156862.7451',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '6296078431.3725',
#    'Operating Expenses': '7441176470.5882',
#    'Operating Income': '3500980392.1569',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '3428431372.549',
#    'Income Tax Expense': '673529411.7647',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '2754901960.7843',
#    'Preferred Dividends': '133333333.3333',
#    'Net Income Com': '2621568627.451',
#    'EPS': '4.6863',
#    'EPS Diluted': '4.6569',
#    'Weighted Average Shs Out': '628152847.0588',
#    'Weighted Average Shs Out (Dil)': '548845098.0392',
#    'Dividend per Share': '3.3235',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.348',
#    'EBIT Margin': '0.3133',
#    'Profit Margin': '0.2353',
#    'Free Cash Flow margin': '-0.6326',
#    'EBITDA': '3889215686.2745',
#    'EBIT': '3428431372.549',
#    'Consolidated Income': '2754901960.7843',
#    'Earnings Before Tax Margin': '0.3133',
#    'Net Profit Margin': '0.2518'},
#   {'date': '2009-10-31',
#    'Revenue': '8768303985.1715',
#    'Revenue Growth': '0.2014',
#    'Cost of Revenue': '0.0',
#    'Gross Profit': '8768303985.1715',
#    'R&D Expenses': '0.0',
#    'SG&A Expense': '5873030583.874',
#    'Operating Expenses': '6840593141.798',
#    'Operating Income': '1927710843.3735',
#    'Interest Expense': '0.0',
#    'Earnings before Tax': '1857275254.8656',
#    'Income Tax Expense': '201112140.8712',
#    'Net Income - Non-Controlling int': '0.0',
#    'Net Income - Discontinued ops': '0.0',
#    'Net Income': '1656163113.9944',
#    'Preferred Dividends': '111214087.1177',
#    'Net Income Com': '1544949026.8767',
#    'EPS': '2.8638',
#    'EPS Diluted': '2.8545',
#    'Weighted Average Shs Out': '530162170.5283',
#    'Weighted Average Shs Out (Dil)': '500735866.5431',
#    'Dividend per Share': '1.9092',
#    'Gross Margin': '1.0',
#    'EBITDA Margin': '0.2428',
#    'EBIT Margin': '0.2118',
#    'Profit Margin': '0.1631',
#    'Free Cash Flow margin': '1.3139',
#    'EBITDA': '2294717330.8619',
#    'EBIT': '1857275254.8656',
#    'Consolidated Income': '1656163113.9944',
#    'Earnings Before Tax Margin': '0.2118',
#    'Net Profit Margin': '0.1889'}]}

# %%
df = pd.DataFrame(columns=list(res['financials'][0].keys()))
for income_statement in res['financials']:
    df = df.append(pd.DataFrame.from_dict({income_statement['date']: income_statement}, orient='index'))

# %%
df.head(3).T
# Out:
#                                         2018-10-31        2017-10-31  \
# date                                    2018-10-31        2017-10-31
# Revenue                           17585496183.2061  17269200930.9542
# Revenue Growth                              0.0183             0.099
# Cost of Revenue                                0.0               0.0
# Gross Profit                      17585496183.2061  17269200930.9542
# R&D Expenses                                   0.0               0.0
# SG&A Expense                       8739694656.4885    8699767261.443
# Operating Expenses                11423664122.1374  11534522885.9581
# Operating Income                   6161832061.0687   5734678044.9961
# Interest Expense                               0.0               0.0
# Earnings before Tax                5656488549.6183   5154383242.8239
# Income Tax Expense                 1496183206.1069   1005430566.3305
# Net Income - Non-Controlling int               0.0      1551590.3801
# Net Income - Discontinued ops                  0.0               0.0
# Net Income                         4160305343.5115   4148952676.4934
# Preferred Dividends                            0.0               0.0
# Net Income Com                     4160305343.5115   4148952676.4934
# EPS                                         6.2519            6.1676
# EPS Diluted                                 6.2366            6.1443
# Weighted Average Shs Out            606119326.7176    594229117.9209
# Weighted Average Shs Out (Dil)      606119326.7176    594229117.9209
# Dividend per Share                          2.2466            2.1226
# Gross Margin                                   1.0               1.0
# EBITDA Margin                               0.2832              0.27
# EBIT Margin                                 0.3217            0.2985
# Profit Margin                               0.1809            0.1862
# Free Cash Flow margin                       0.7391            0.0951
# EBITDA                             6516793893.1298   6010085337.4709
# EBIT                               5656488549.6183   5154383242.8239
# Consolidated Income                4160305343.5115   4150504266.8735
# Earnings Before Tax Margin                  0.3217            0.2985
# Net Profit Margin                           0.2366            0.2403
#
#                                         2016-10-31
# date                                    2016-10-31
# Revenue                           15713114754.0984
# Revenue Growth                              0.0608
# Cost of Revenue                                0.0
# Gross Profit                      15713114754.0984
# R&D Expenses                                   0.0
# SG&A Expense                       8154992548.4352
# Operating Expenses                10867362146.0507
# Operating Income                   4845752608.0477
# Interest Expense                               0.0
# Earnings before Tax                4264530551.4158
# Income Tax Expense                  820417287.6304
# Net Income - Non-Controlling int      6706408.3458
# Net Income - Discontinued ops                  0.0
# Net Income                         3444113263.7854
# Preferred Dividends                            0.0
# Net Income Com                     3444113263.7854
# EPS                                         5.1714
# EPS Diluted                                 5.1565
# Weighted Average Shs Out            550509195.9762
# Weighted Average Shs Out (Dil)      550509195.9762
# Dividend per Share                          1.9031
# Gross Margin                                   1.0
# EBITDA Margin                               0.2392
# EBIT Margin                                 0.2714
# Profit Margin                               0.1632
# Free Cash Flow margin                      -0.1583
# EBITDA                             5044709388.9717
# EBIT                               4264530551.4158
# Consolidated Income                3450819672.1311
# Earnings Before Tax Margin                  0.2714
# Net Profit Margin                           0.2192

# %%
df['Net Income'].astype('float64')-df['Preferred Dividends'].astype('float64')
# Out:
# 2018-10-31    4.160305e+09
# 2017-10-31    4.148953e+09
# 2016-10-31    3.444113e+09
# 2015-10-31    3.338426e+09
# 2014-10-31    3.801778e+09
# 2013-10-31    3.955939e+09
# 2012-10-31    4.082000e+09
# 2011-10-31    3.053213e+09
# 2010-10-31    2.621569e+09
# 2009-10-31    1.544949e+09
# dtype: float64

# %%
res = api.company_valuation.financial_ratios(tickers)
# Out:
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financial-ratios/BMO, path: financial-ratios/BMO

# %%
res
# Out:
# {'symbol': 'BMO',
#  'ratios': [{'date': '2018-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '2.5761',
#     'priceEarningsRatio': '11.9548',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '3.4855',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '3.2481969911075',
#     'priceEarningsToGrowthRatio': '10.675542110957',
#     'priceSalesRatio': '2.5255764424499',
#     'dividendYield': '0.044378211707266',
#     'enterpriseValueMultiple': '17.040998536338',
#     'priceFairValue': '1.2723709078819'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.73549257759785',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.32165646568564',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.35039284629075',
#     'netProfitMargin': '0.23657594304814',
#     'effectiveTaxRate': '0.26450742240217',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1192',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.73549257759785',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.32165646568564'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '11.599697885197',
#     'assetTurnover': '0.029761720203398'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '0.21715490069309',
#     'cashRatio': '0.076277396637558',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.0775',
#     'debtEquityRatio': '1.3121',
#     'longtermDebtToCapitalization': '0.44625217826206',
#     'totalDebtToCapitalization': '0.46997301007169',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '0.44177022200054',
#     'companyEquityMultiplier': '16.927592013471'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '29.5503',
#     'freeCashFlowPerShare': '28.0887',
#     'cashPerShare': '83.225',
#     'payoutRatio': '0.3595',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '0.77753179667492',
#     'freeCashFlowOperatingCashFlowRatio': '0.95053595355069',
#     'cashFlowCoverageRatios': '0.44177022200054',
#     'shortTermCoverageRatios': '4.8467595285853',
#     'capitalExpenditureCoverageRatios': '20.216704288939',
#     'dividendpaidAndCapexCoverageRatios': '5.1649365628605',
#     'dividendPayoutRatio': '0.4737614678899'}},
#   {'date': '2017-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '2.6361',
#     'priceEarningsRatio': '12.4214',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '27.7186',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '18.961704679874',
#     'priceEarningsToGrowthRatio': '10.310515558914',
#     'priceSalesRatio': '2.4771175745316',
#     'dividendYield': '0.036452244691674',
#     'enterpriseValueMultiple': '16.229869266693',
#     'priceFairValue': '1.2431942374774'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.80493678506923',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.2984725965858',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.33207547169811',
#     'netProfitMargin': '0.24025157232704',
#     'effectiveTaxRate': '0.19506321493077',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1206',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.80493678506923',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.2984725965858'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '10.949335956715',
#     'assetTurnover': '0.031370669973787'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '0.1988429706622',
#     'cashRatio': '0.06444206077709',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.0817',
#     'debtEquityRatio': '1.3076',
#     'longtermDebtToCapitalization': '0.41529580068645',
#     'totalDebtToCapitalization': '0.44208520700744',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '0.082741521745881',
#     'companyEquityMultiplier': '15.998106146007'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '4.8937',
#     'freeCashFlowPerShare': '3.5626',
#     'cashPerShare': '65.7806',
#     'payoutRatio': '0.3445',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '0.13063791554357',
#     'freeCashFlowOperatingCashFlowRatio': '0.7279917469051',
#     'cashFlowCoverageRatios': '0.082741521745881',
#     'shortTermCoverageRatios': '0.79836706079673',
#     'capitalExpenditureCoverageRatios': '3.676359039191',
#     'dividendpaidAndCapexCoverageRatios': '1.0382006426276',
#     'dividendPayoutRatio': '0.37584143605085'}},
#   {'date': '2016-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '2.2282',
#     'priceEarningsRatio': '12.2984',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '',
#     'priceEarningsToGrowthRatio': '9.1888216004775',
#     'priceSalesRatio': '2.0140718659556',
#     'dividendYield': '0.052247743808575',
#     'enterpriseValueMultiple': '16.921684702719',
#     'priceFairValue': '1.0039413161263'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.8076183819675',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.27139944041352',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.30838905486793',
#     'netProfitMargin': '0.21918717693366',
#     'effectiveTaxRate': '0.1923816180325',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1093',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.8076183819675',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.27139944041352'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '9.8216115510016',
#     'assetTurnover': '0.030652605260672'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '0.18283278223008',
#     'cashRatio': '0.061507772161619',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.0985',
#     'debtEquityRatio': '1.602',
#     'longtermDebtToCapitalization': '0.45965741789817',
#     'totalDebtToCapitalization': '0.48659450229099',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '-0.068038738001883',
#     'companyEquityMultiplier': '16.26170102118'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '-4.9551',
#     'freeCashFlowPerShare': '-6.0649',
#     'cashPerShare': '65.5755',
#     'payoutRatio': '0.3681',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '-0.12936880542514',
#     'freeCashFlowOperatingCashFlowRatio': '',
#     'cashFlowCoverageRatios': '-0.068038738001883',
#     'shortTermCoverageRatios': '-0.6641131111564',
#     'capitalExpenditureCoverageRatios': '-4.4648117839609',
#     'dividendpaidAndCapexCoverageRatios': '-0.96395759717317',
#     'dividendPayoutRatio': '0.48009519688445'}},
#   {'date': '2015-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '2.2502',
#     'priceEarningsRatio': '11.4671',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '25.2771',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '16.813950048327',
#     'priceEarningsToGrowthRatio': '8.6570681026855',
#     'priceSalesRatio': '1.9511778641877',
#     'dividendYield': '0.056434620428962',
#     'enterpriseValueMultiple': '19.635524878362',
#     'priceFairValue': '0.9596516566571'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.82359592913683',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.27366032286348',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.30702975914178',
#     'netProfitMargin': '0.22538552787663',
#     'effectiveTaxRate': '0.17640407086317',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1109',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.82359592913683',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.27366032286348'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '8.4853391684903',
#     'assetTurnover': '0.030206533609812'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '0.22255785226785',
#     'cashRatio': '0.086521877957605',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.1064',
#     'debtEquityRatio': '1.7321',
#     'longtermDebtToCapitalization': '0.46417480085392',
#     'totalDebtToCapitalization': '0.492798540239',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '0.058742840998388',
#     'companyEquityMultiplier': '16.282304297093'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '3.8974',
#     'freeCashFlowPerShare': '2.9898',
#     'cashPerShare': '82.5859',
#     'payoutRatio': '0.3881',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '0.11604518025685',
#     'freeCashFlowOperatingCashFlowRatio': '0.76711111111109',
#     'cashFlowCoverageRatios': '0.058742840998388',
#     'shortTermCoverageRatios': '0.54190246221833',
#     'capitalExpenditureCoverageRatios': '4.2938931297706',
#     'dividendpaidAndCapexCoverageRatios': '0.84618277547951',
#     'dividendPayoutRatio': '0.48855835240272'}},
#   {'date': '2014-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '2.8873',
#     'priceEarningsRatio': '12.6826',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '',
#     'priceEarningsToGrowthRatio': '10.221589788695',
#     'priceSalesRatio': '2.3990418441667',
#     'dividendYield': '0.042339792039993',
#     'enterpriseValueMultiple': '13.196176738021',
#     'priceFairValue': '1.2740867754568'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.82567567567569',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.28425615979806',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.31811447072381',
#     'netProfitMargin': '0.23470339680624',
#     'effectiveTaxRate': '0.17432432432433',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1246',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.82567567567569',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.28425615979806'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '8.0065905096661',
#     'assetTurnover': '0.030956801815652'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.112',
#     'debtEquityRatio': '1.9211',
#     'longtermDebtToCapitalization': '0',
#     'totalDebtToCapitalization': '0',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '17.155567860578'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '-4.5435',
#     'freeCashFlowPerShare': '-5.6876',
#     'cashPerShare': '53.5476',
#     'payoutRatio': '0.4329',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '-0.16062119299786',
#     'freeCashFlowOperatingCashFlowRatio': '',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '-3.9715061058346',
#     'dividendpaidAndCapexCoverageRatios': '-1.1309891808347',
#     'dividendPayoutRatio': '0.43277998597146'}},
#   {'date': '2013-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '3.0619',
#     'priceEarningsRatio': '11.7556',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '4.7586',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '0',
#     'priceEarningsToGrowthRatio': '0',
#     'priceSalesRatio': '0',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '5.5463514203096',
#     'priceFairValue': '0'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.79652844744456',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.30808080808081',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.34682115270351',
#     'netProfitMargin': '0.24539512774807',
#     'effectiveTaxRate': '0.20347155255544',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1372',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.79652844744456',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.30808080808081'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '7.7629151291514',
#     'assetTurnover': '0.031338214373496'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.1088',
#     'debtEquityRatio': '1.9403',
#     'longtermDebtToCapitalization': '0',
#     'totalDebtToCapitalization': '0',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '17.837845019431'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '16.1592',
#     'freeCashFlowPerShare': '15.2908',
#     'cashPerShare': '46.0418',
#     'payoutRatio': '0.4636',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '0.67997623291741',
#     'freeCashFlowOperatingCashFlowRatio': '0.94626004893394',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '18.608130081301',
#     'dividendpaidAndCapexCoverageRatios': '4.5575467941059',
#     'dividendPayoutRatio': '0.4590799031477'}},
#   {'date': '2012-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '2.745',
#     'priceEarningsRatio': '9.6444',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '4.5561',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '0',
#     'priceEarningsToGrowthRatio': '0',
#     'priceSalesRatio': '0',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '4.6615821213196',
#     'priceFairValue': '0'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.82364810330912',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.31113064222487',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.36373909222173',
#     'netProfitMargin': '0.25626216334987',
#     'effectiveTaxRate': '0.17635189669088',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1425',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.82364810330912',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.31113064222487'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '7.513679245283',
#     'assetTurnover': '0.030315025816016'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.1451',
#     'debtEquityRatio': '2.6616',
#     'longtermDebtToCapitalization': '0',
#     'totalDebtToCapitalization': '0',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '18.337079043797'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '13.8737',
#     'freeCashFlowPerShare': '12.9759',
#     'cashPerShare': '35.5354',
#     'payoutRatio': '0.462',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '0.64417100885178',
#     'freeCashFlowOperatingCashFlowRatio': '0.93528895819121',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '15.453313253012',
#     'dividendpaidAndCapexCoverageRatios': '4.9260681709073',
#     'dividendPayoutRatio': '0.34762371386575'}},
#   {'date': '2011-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '2.7816',
#     'priceEarningsRatio': '12.0272',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '35.808',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '0',
#     'priceEarningsToGrowthRatio': '0',
#     'priceSalesRatio': '0',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '5.7589225589225',
#     'priceFairValue': '0'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.77635945876946',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.28092949867317',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.37309043964714',
#     'netProfitMargin': '0.21810227354228',
#     'effectiveTaxRate': '0.22364054123054',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1154',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.77635945876946',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.28092949867317'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '6.7651625424552',
#     'assetTurnover': '0.027853967936873'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.1528',
#     'debtEquityRatio': '2.9025',
#     'longtermDebtToCapitalization': '0',
#     'totalDebtToCapitalization': '0',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '18.994991082609'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '2.7223',
#     'freeCashFlowPerShare': '1.6458',
#     'cashPerShare': '43.2197',
#     'payoutRatio': '0.7279',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '0.11590045183964',
#     'freeCashFlowOperatingCashFlowRatio': '0.60457920792077',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '2.5289514866982',
#     'dividendpaidAndCapexCoverageRatios': '0.70199826238058',
#     'dividendPayoutRatio': '0.5468595856626'}},
#   {'date': '2010-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '3.3985',
#     'priceEarningsRatio': '12.6326',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '0.0',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '',
#     'priceEarningsToGrowthRatio': '0',
#     'priceSalesRatio': '0',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '5.7012856062516',
#     'priceFairValue': '0'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.8035458964827',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.31332317892662',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.31995340919273',
#     'netProfitMargin': '0.2517695546994',
#     'effectiveTaxRate': '0.1964541035173',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.1392',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.8035458964827',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.31332317892662'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '7.4061048440608',
#     'assetTurnover': '0.02549861780631'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.15',
#     'debtEquityRatio': '3.253',
#     'longtermDebtToCapitalization': '0',
#     'totalDebtToCapitalization': '0',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '21.688137944703'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '-11.996',
#     'freeCashFlowPerShare': '-12.8633',
#     'cashPerShare': '41.208',
#     'payoutRatio': '0.7098',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '-0.58991129827076',
#     'freeCashFlowOperatingCashFlowRatio': '',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '-13.831932773108',
#     'dividendpaidAndCapexCoverageRatios': '-3.9878861296184',
#     'dividendPayoutRatio': '0.41814946619216'}},
#   {'date': '2009-10-31',
#    'investmentValuationRatios': {'priceBookValueRatio': '',
#     'priceToBookRatio': '',
#     'priceToSalesRatio': '2.8128',
#     'priceEarningsRatio': '16.2442',
#     'receivablesTurnover': '0.0',
#     'priceToFreeCashFlowsRatio': '2.0219',
#     'priceToOperatingCashFlowsRatio': '3.4929',
#     'priceCashFlowRatio': '0',
#     'priceEarningsToGrowthRatio': '0',
#     'priceSalesRatio': '0',
#     'dividendYield': '',
#     'enterpriseValueMultiple': '5.3695476575121',
#     'priceFairValue': '0'},
#    'profitabilityIndicatorRatios': {'niperEBT': '0.89171656686625',
#     'ebtperEBIT': '1',
#     'ebitperRevenue': '0.21181693267096',
#     'grossProfitMargin': '1',
#     'operatingProfitMargin': '1',
#     'pretaxProfitMargin': '0.21984991015749',
#     'netProfitMargin': '0.18888066800549',
#     'effectiveTaxRate': '0.10828343313375',
#     'returnOnAssets': '',
#     'returnOnEquity': '0.0885',
#     'returnOnCapitalEmployed': '',
#     'nIperEBT': '0.89171656686625',
#     'eBTperEBIT': '1',
#     'eBITperRevenue': '0.21181693267096'},
#    'operatingPerformanceRatios': {'receivablesTurnover': '0.0',
#     'payablesTurnover': '',
#     'inventoryTurnover': '0.0',
#     'fixedAssetTurnover': '5.7900856793145',
#     'assetTurnover': '0.024355271354947'},
#    'liquidityMeasurementRatios': {'currentRatio': '',
#     'quickRatio': '',
#     'cashRatio': '',
#     'daysOfSalesOutstanding': '0.0',
#     'daysOfInventoryOutstanding': '0.0',
#     'operatingCycle': '',
#     'daysOfPayablesOutstanding': '0.0',
#     'cashConversionCycle': ''},
#    'debtRatios': {'debtRatio': '0.1572',
#     'debtEquityRatio': '3.0235',
#     'longtermDebtToCapitalization': '0',
#     'totalDebtToCapitalization': '0',
#     'interestCoverage': '0.0',
#     'cashFlowToDebtRatio': '',
#     'companyEquityMultiplier': '19.233450512452'},
#    'cashFlowIndicatorRatios': {'operatingCashFlowPerShare': '25.55',
#     'freeCashFlowPerShare': '24.825',
#     'cashPerShare': '26.5505',
#     'payoutRatio': '0.6664',
#     'receivablesTurnover': '0.0',
#     'operatingCashFlowSalesRatio': '1.3522883416129',
#     'freeCashFlowOperatingCashFlowRatio': '0.97162732530874',
#     'cashFlowCoverageRatios': '',
#     'shortTermCoverageRatios': '',
#     'capitalExpenditureCoverageRatios': '35.245179063366',
#     'dividendpaidAndCapexCoverageRatios': '7.6382089552241',
#     'dividendPayoutRatio': '0.73419138220483'}}]}

# %%
df_ratios = pd.DataFrame(columns=list(res['ratios'][0].keys()))
for ratio in res['ratios']:
    df_ratios = df_ratios.append(pd.DataFrame.from_dict({ratio['date']: ratio['investmentValuationRatios']}, orient='index'))
# Out:
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financial-ratios/BMO, path: financial-ratios/BMO

# %%
df_ratios
# Out:
#            cashFlowIndicatorRatios date debtRatios      dividendYield  \
# 2018-10-31                     NaN  NaN        NaN  0.044378211707266
# 2017-10-31                     NaN  NaN        NaN  0.036452244691674
# 2016-10-31                     NaN  NaN        NaN  0.052247743808575
# 2015-10-31                     NaN  NaN        NaN  0.056434620428962
# 2014-10-31                     NaN  NaN        NaN  0.042339792039993
# 2013-10-31                     NaN  NaN        NaN
# 2012-10-31                     NaN  NaN        NaN
# 2011-10-31                     NaN  NaN        NaN
# 2010-10-31                     NaN  NaN        NaN
# 2009-10-31                     NaN  NaN        NaN
#
#            enterpriseValueMultiple investmentValuationRatios  \
# 2018-10-31         17.040998536338                       NaN
# 2017-10-31         16.229869266693                       NaN
# 2016-10-31         16.921684702719                       NaN
# 2015-10-31         19.635524878362                       NaN
# 2014-10-31         13.196176738021                       NaN
# 2013-10-31         5.5463514203096                       NaN
# 2012-10-31         4.6615821213196                       NaN
# 2011-10-31         5.7589225589225                       NaN
# 2010-10-31         5.7012856062516                       NaN
# 2009-10-31         5.3695476575121                       NaN
#
#            liquidityMeasurementRatios operatingPerformanceRatios  \
# 2018-10-31                        NaN                        NaN
# 2017-10-31                        NaN                        NaN
# 2016-10-31                        NaN                        NaN
# 2015-10-31                        NaN                        NaN
# 2014-10-31                        NaN                        NaN
# 2013-10-31                        NaN                        NaN
# 2012-10-31                        NaN                        NaN
# 2011-10-31                        NaN                        NaN
# 2010-10-31                        NaN                        NaN
# 2009-10-31                        NaN                        NaN
#
#            priceBookValueRatio priceCashFlowRatio priceEarningsRatio  \
# 2018-10-31                        3.2481969911075            11.9548
# 2017-10-31                        18.961704679874            12.4214
# 2016-10-31                                                   12.2984
# 2015-10-31                        16.813950048327            11.4671
# 2014-10-31                                                   12.6826
# 2013-10-31                                      0            11.7556
# 2012-10-31                                      0             9.6444
# 2011-10-31                                      0            12.0272
# 2010-10-31                                                   12.6326
# 2009-10-31                                      0            16.2442
#
#            priceEarningsToGrowthRatio   priceFairValue  priceSalesRatio  \
# 2018-10-31            10.675542110957  1.2723709078819  2.5255764424499
# 2017-10-31            10.310515558914  1.2431942374774  2.4771175745316
# 2016-10-31            9.1888216004775  1.0039413161263  2.0140718659556
# 2015-10-31            8.6570681026855  0.9596516566571  1.9511778641877
# 2014-10-31            10.221589788695  1.2740867754568  2.3990418441667
# 2013-10-31                          0                0                0
# 2012-10-31                          0                0                0
# 2011-10-31                          0                0                0
# 2010-10-31                          0                0                0
# 2009-10-31                          0                0                0
#
#            priceToBookRatio priceToFreeCashFlowsRatio  \
# 2018-10-31                                     3.4855
# 2017-10-31                                    27.7186
# 2016-10-31                                        0.0
# 2015-10-31                                    25.2771
# 2014-10-31                                        0.0
# 2013-10-31                                     4.7586
# 2012-10-31                                     4.5561
# 2011-10-31                                     35.808
# 2010-10-31                                        0.0
# 2009-10-31                                     2.0219
#
#            priceToOperatingCashFlowsRatio priceToSalesRatio  \
# 2018-10-31                         3.4929            2.5761
# 2017-10-31                         3.4929            2.6361
# 2016-10-31                         3.4929            2.2282
# 2015-10-31                         3.4929            2.2502
# 2014-10-31                         3.4929            2.8873
# 2013-10-31                         3.4929            3.0619
# 2012-10-31                         3.4929             2.745
# 2011-10-31                         3.4929            2.7816
# 2010-10-31                         3.4929            3.3985
# 2009-10-31                         3.4929            2.8128
#
#            profitabilityIndicatorRatios receivablesTurnover
# 2018-10-31                          NaN                 0.0
# 2017-10-31                          NaN                 0.0
# 2016-10-31                          NaN                 0.0
# 2015-10-31                          NaN                 0.0
# 2014-10-31                          NaN                 0.0
# 2013-10-31                          NaN                 0.0
# 2012-10-31                          NaN                 0.0
# 2011-10-31                          NaN                 0.0
# 2010-10-31                          NaN                 0.0
# 2009-10-31                          NaN                 0.0

# %%
df_ratios['priceToBookRatio']
# Out:
# 2018-10-31
# 2017-10-31
# 2016-10-31
# 2015-10-31
# 2014-10-31
# 2013-10-31
# 2012-10-31
# 2011-10-31
# 2010-10-31
# 2009-10-31
# Name: priceToBookRatio, dtype: object

# %%
df_debtratios = pd.DataFrame(columns=list(res['ratios'][0]['debtRatios'].keys()))
for ratio in res['ratios']:
    df_debtratios = df_debtratios.append(pd.DataFrame.from_dict({ratio['date']: ratio['debtRatios']}, orient='index'))
df_debtratios
# Out:
#            debtRatio debtEquityRatio longtermDebtToCapitalization  \
# 2018-10-31    0.0775          1.3121             0.44625217826206
# 2017-10-31    0.0817          1.3076             0.41529580068645
# 2016-10-31    0.0985           1.602             0.45965741789817
# 2015-10-31    0.1064          1.7321             0.46417480085392
# 2014-10-31     0.112          1.9211                            0
# 2013-10-31    0.1088          1.9403                            0
# 2012-10-31    0.1451          2.6616                            0
# 2011-10-31    0.1528          2.9025                            0
# 2010-10-31      0.15           3.253                            0
# 2009-10-31    0.1572          3.0235                            0
#
#            totalDebtToCapitalization interestCoverage cashFlowToDebtRatio  \
# 2018-10-31          0.46997301007169              0.0    0.44177022200054
# 2017-10-31          0.44208520700744              0.0   0.082741521745881
# 2016-10-31          0.48659450229099              0.0  -0.068038738001883
# 2015-10-31            0.492798540239              0.0   0.058742840998388
# 2014-10-31                         0              0.0
# 2013-10-31                         0              0.0
# 2012-10-31                         0              0.0
# 2011-10-31                         0              0.0
# 2010-10-31                         0              0.0
# 2009-10-31                         0              0.0
#
#            companyEquityMultiplier
# 2018-10-31         16.927592013471
# 2017-10-31         15.998106146007
# 2016-10-31          16.26170102118
# 2015-10-31         16.282304297093
# 2014-10-31         17.155567860578
# 2013-10-31         17.837845019431
# 2012-10-31         18.337079043797
# 2011-10-31         18.994991082609
# 2010-10-31         21.688137944703
# 2009-10-31         19.233450512452

# %%
df_cashFlowIndicatorRatios = pd.DataFrame(columns=list(res['ratios'][0]['cashFlowIndicatorRatios'].keys()))
for ratio in res['ratios']:
    df_cashFlowIndicatorRatios = df_cashFlowIndicatorRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['cashFlowIndicatorRatios']}, orient='index'))
df_cashFlowIndicatorRatios
# Out:
#            operatingCashFlowPerShare freeCashFlowPerShare cashPerShare  \
# 2018-10-31                   29.5503              28.0887       83.225
# 2017-10-31                    4.8937               3.5626      65.7806
# 2016-10-31                   -4.9551              -6.0649      65.5755
# 2015-10-31                    3.8974               2.9898      82.5859
# 2014-10-31                   -4.5435              -5.6876      53.5476
# 2013-10-31                   16.1592              15.2908      46.0418
# 2012-10-31                   13.8737              12.9759      35.5354
# 2011-10-31                    2.7223               1.6458      43.2197
# 2010-10-31                   -11.996             -12.8633       41.208
# 2009-10-31                     25.55               24.825      26.5505
#
#            payoutRatio receivablesTurnover operatingCashFlowSalesRatio  \
# 2018-10-31      0.3595                 0.0            0.77753179667492
# 2017-10-31      0.3445                 0.0            0.13063791554357
# 2016-10-31      0.3681                 0.0           -0.12936880542514
# 2015-10-31      0.3881                 0.0            0.11604518025685
# 2014-10-31      0.4329                 0.0           -0.16062119299786
# 2013-10-31      0.4636                 0.0            0.67997623291741
# 2012-10-31       0.462                 0.0            0.64417100885178
# 2011-10-31      0.7279                 0.0            0.11590045183964
# 2010-10-31      0.7098                 0.0           -0.58991129827076
# 2009-10-31      0.6664                 0.0             1.3522883416129
#
#            freeCashFlowOperatingCashFlowRatio cashFlowCoverageRatios  \
# 2018-10-31                   0.95053595355069       0.44177022200054
# 2017-10-31                    0.7279917469051      0.082741521745881
# 2016-10-31                                        -0.068038738001883
# 2015-10-31                   0.76711111111109      0.058742840998388
# 2014-10-31
# 2013-10-31                   0.94626004893394
# 2012-10-31                   0.93528895819121
# 2011-10-31                   0.60457920792077
# 2010-10-31
# 2009-10-31                   0.97162732530874
#
#            shortTermCoverageRatios capitalExpenditureCoverageRatios  \
# 2018-10-31         4.8467595285853                  20.216704288939
# 2017-10-31        0.79836706079673                   3.676359039191
# 2016-10-31        -0.6641131111564                 -4.4648117839609
# 2015-10-31        0.54190246221833                  4.2938931297706
# 2014-10-31                                         -3.9715061058346
# 2013-10-31                                          18.608130081301
# 2012-10-31                                          15.453313253012
# 2011-10-31                                          2.5289514866982
# 2010-10-31                                         -13.831932773108
# 2009-10-31                                          35.245179063366
#
#            dividendpaidAndCapexCoverageRatios dividendPayoutRatio
# 2018-10-31                    5.1649365628605     0.4737614678899
# 2017-10-31                    1.0382006426276    0.37584143605085
# 2016-10-31                  -0.96395759717317    0.48009519688445
# 2015-10-31                   0.84618277547951    0.48855835240272
# 2014-10-31                   -1.1309891808347    0.43277998597146
# 2013-10-31                    4.5575467941059     0.4590799031477
# 2012-10-31                    4.9260681709073    0.34762371386575
# 2011-10-31                   0.70199826238058     0.5468595856626
# 2010-10-31                   -3.9878861296184    0.41814946619216
# 2009-10-31                    7.6382089552241    0.73419138220483

# %%
res = api.company_valuation.financial_ratios(['FB'])

df_ratios = pd.DataFrame(columns=list(res['ratios'][0].keys()))
for ratio in res['ratios']:
    df_ratios = df_ratios.append(pd.DataFrame.from_dict({ratio['date']: ratio['investmentValuationRatios']}, orient='index'))
df_ratios['priceToBookRatio']
# Out:
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financial-ratios/FB, path: financial-ratios/FB
# 2018-12-31      4.848
# 2017-12-31     8.1953
# 2016-12-31     7.5992
# 2015-12-31    10.5049
# 2014-12-31    11.9297
# 2013-12-31     8.2992
# 2012-12-31     4.6039
# 2011-12-31     7.7201
# 2010-12-31     7.7201
# Name: priceToBookRatio, dtype: object
