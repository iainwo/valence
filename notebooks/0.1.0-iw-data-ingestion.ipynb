# %% [markdown]
# ---
# # Data Ingestion
# ---
# Notebook: 0.1.0-iw-data-ingestion.ipynb<br>
# Dependencies: requirements.txt<br>
# Date: 2019-OCT-3<br>
# Abstract:
# ```
#     The goal of this notebook is ingest stock data from the Financial Modelling Prep API and form a dataframe. This dataframe will be exported to the raw unprocessed directory.
# ```

# %% [markdown]
# ---
# ## 0. Setup
# ---

# %%
import pandas as pd

import fmpclient
from fmpclient import FMPClient
api = FMPClient()
fmpclient.__version__
# Out:
# '0.1.3'

# %% [markdown]
# ---
# ## 1. Pull data from API
# ---

# %%
tickers = ['TRP']

# %%
res_income_statements = api.company_valuation.income_statement(tickers, period='quarter')
res_financial_ratios  = api.company_valuation.financial_ratios(tickers)
res_balance_sheet     = api.company_valuation.balance_sheet_statement(tickers, period='quarter')
res_cash_flow         = api.company_valuation.cash_flow_statement(tickers, period='quarter')
res_enterprise_value  = api.company_valuation.enterprise_value(tickers, period='quarter')
res_historical_dcf    = api.company_valuation.historical_discounted_cash_flow_value(tickers, period='quarter')
res_dcf               = api.company_valuation.discounted_cash_flow_value(tickers)
res_metrics           = api.company_valuation.key_metrics(tickers, period='quarter')
res_profile           = api.company_valuation.profile(tickers)
# Out:
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financials/income-statement/TRP, path: financials/income-statement/TRP
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financial-ratios/TRP, path: financial-ratios/TRP
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/TRP, path: financials/balance-sheet-statement/TRP
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financials/cash-flow-statement/TRP, path: financials/cash-flow-statement/TRP
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/enterprise-value/TRP, path: enterprise-value/TRP
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/company/historical-discounted-cash-flow/TRP, path: company/historical-discounted-cash-flow/TRP
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/company/discounted-cash-flow/TRP, path: company/discounted-cash-flow/TRP
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/company-key-metrics/TRP, path: company-key-metrics/TRP
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/company/profile/TRP, path: company/profile/TRP

# %% [markdown]
# #### Create Dataframe for the Income Statements

# %%
df_income_statements = pd.DataFrame(columns=list(res_income_statements['financials'][0].keys()))
for income_statement in res_income_statements['financials']:
    df_income_statements = df_income_statements.append(pd.DataFrame.from_dict({income_statement['date']: income_statement}, orient='index'))
df_income_statements.head()
# Out:
#                   date       Revenue Revenue Growth Cost of Revenue  \
# 2019-03-31  2019-03-31  3487000000.0         0.0184
# 2018-12-31  2018-12-31  3904000000.0
# 2018-09-30  2018-09-30  3156000000.0
# 2018-06-30  2018-06-30  3195000000.0
#
#             Gross Profit R&D Expenses SG&A Expense Operating Expenses  \
# 2019-03-31  1698000000.0                              1480038948.3934
# 2018-12-31  1963000000.0                              1511482867.4151
# 2018-09-30  1390000000.0                              1454699147.0068
# 2018-06-30  1479000000.0                              1410237052.6952
#
#            Operating Income Interest Expense  ... Gross Margin EBITDA Margin  \
# 2019-03-31     1511000000.0  -438918433.0762  ...        0.487
# 2018-12-31     1823000000.0  -442438917.0152  ...       0.5028
# 2018-09-30     1263000000.0  -443402751.0951  ...       0.4404
# 2018-06-30     1327000000.0  -421259248.0749  ...       0.4629
#
#            EBIT Margin Profit Margin Free Cash Flow margin EBITDA  \
# 2019-03-31      0.3246
# 2018-12-31      0.3466
# 2018-09-30      0.3075
# 2018-06-30      0.3136
#
#                        EBIT Consolidated Income Earnings Before Tax Margin  \
# 2019-03-31  1131750430.6793                                         0.3963
# 2018-12-31  1352997285.2007                                         0.1939
# 2018-09-30   970567893.6448                                         0.3638
# 2018-06-30  1001811867.7337                                         0.3302
#
#            Net Profit Margin
# 2019-03-31
# 2018-12-31
# 2018-09-30
# 2018-06-30
#
# [4 rows x 32 columns]

# %% [markdown]
# #### Create Dataframe for the Financial Ratios

# %%
df_ratios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['investmentValuationRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_ratios = df_ratios.append(pd.DataFrame.from_dict({ratio['date']: ratio['investmentValuationRatios']}, orient='index'))

df_debtratios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['debtRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_debtratios = df_debtratios.append(pd.DataFrame.from_dict({ratio['date']: ratio['debtRatios']}, orient='index'))

df_cashFlowIndicatorRatios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['cashFlowIndicatorRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_cashFlowIndicatorRatios = df_cashFlowIndicatorRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['cashFlowIndicatorRatios']}, orient='index'))

df_profitabilityIndicatorRatios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['profitabilityIndicatorRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_profitabilityIndicatorRatios = df_profitabilityIndicatorRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['profitabilityIndicatorRatios']}, orient='index'))
    
df_operatingPerformanceRatios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['operatingPerformanceRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_operatingPerformanceRatios = df_operatingPerformanceRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['operatingPerformanceRatios']}, orient='index'))
    
df_liquidityMeasurementRatios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['liquidityMeasurementRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_liquidityMeasurementRatios = df_liquidityMeasurementRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['liquidityMeasurementRatios']}, orient='index'))

# %%
df_ratios.head(1)
# Out:
#            priceBookValueRatio priceToBookRatio priceToSalesRatio  \
# 2018-12-31                                                 2.3002
#
#            priceEarningsRatio receivablesTurnover priceToFreeCashFlowsRatio  \
# 2018-12-31            12.2947              5.2515                       0.0
#
#            priceToOperatingCashFlowsRatio priceCashFlowRatio  \
# 2018-12-31                         6.7495    4.8519068497326
#
#            priceEarningsToGrowthRatio  priceSalesRatio      dividendYield  \
# 2018-12-31            8.5910992436515  2.3250419913735  0.049395914999966
#
#            enterpriseValueMultiple   priceFairValue
# 2018-12-31         8.7172533318092  1.0840633103824

# %%
df_debtratios.head(1)
# Out:
#            debtRatio debtEquityRatio longtermDebtToCapitalization  \
# 2018-12-31    0.5079          1.7125              0.6000545293436
#
#            totalDebtToCapitalization interestCoverage cashFlowToDebtRatio  \
# 2018-12-31          0.63133489991078           2.8252    0.13047112915746
#
#            companyEquityMultiplier
# 2018-12-31         3.3717363146772

# %%
df_cashFlowIndicatorRatios.head(1)
# Out:
#            operatingCashFlowPerShare freeCashFlowPerShare cashPerShare  \
# 2018-12-31                    9.8112              -4.3241       0.6676
#
#            payoutRatio receivablesTurnover operatingCashFlowSalesRatio  \
# 2018-12-31      0.5348              5.2515            0.47920169603042
#
#            freeCashFlowOperatingCashFlowRatio cashFlowCoverageRatios  \
# 2018-12-31                  -0.44073226544622       0.13047112915746
#
#            shortTermCoverageRatios capitalExpenditureCoverageRatios  \
# 2018-12-31         1.0531812339332                  0.6940914866582
#
#            dividendpaidAndCapexCoverageRatios dividendPayoutRatio
# 2018-12-31                   0.59509759418974    0.42436520799568

# %%
df_profitabilityIndicatorRatios.head(1)
# Out:
#                    niperEBT        ebtperEBIT    ebitperRevenue  \
# 2018-12-31  0.8955007256894  0.64603844350679  0.46779735360772
#
#            grossProfitMargin operatingProfitMargin pretaxProfitMargin  \
# 2018-12-31  0.62870092843044                     1   0.35675122450471
#
#              netProfitMargin effectiveTaxRate returnOnAssets returnOnEquity  \
# 2018-12-31  0.27063381826157  0.1044992743106         0.0662         0.1262
#
#            returnOnCapitalEmployed         nIperEBT        eBTperEBIT  \
# 2018-12-31                  0.0339  0.8955007256894  0.64603844350679
#
#               eBITperRevenue
# 2018-12-31  0.46779735360772

# %%
df_operatingPerformanceRatios.head(1)
# Out:
#            receivablesTurnover payablesTurnover inventoryTurnover  \
# 2018-12-31              5.2515           1.0855           32.8876
#
#            fixedAssetTurnover     assetTurnover
# 2018-12-31   0.20568996887358  0.13828346138294

# %%
df_liquidityMeasurementRatios.head(1)
# Out:
#            currentRatio        quickRatio          cashRatio  \
# 2018-12-31       0.2941  0.23026417426233  0.034450795612548
#
#            daysOfSalesOutstanding daysOfInventoryOutstanding operatingCycle  \
# 2018-12-31               -30.9736                     67.642
#
#            daysOfPayablesOutstanding cashConversionCycle
# 2018-12-31                  144.3029

# %% [markdown]
# #### Create DataFrame for Balance Sheet

# %%
df_balance_sheet = pd.DataFrame(columns=list(res_balance_sheet['financials'][0].keys()))
for ratio in res_balance_sheet['financials']:
    df_balance_sheet = df_balance_sheet.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))
df_balance_sheet.head()
# Out:
#                   date Cash and cash equivalents Short-term investments  \
# 2019-03-31  2019-03-31            653134596.6594                    0.0
# 2018-12-31  2018-12-31               446000000.0                    0.0
# 2018-09-30  2018-09-30            846076999.9232                    0.0
# 2018-06-30  2018-06-30           1185263475.7663                    0.0
#
#            Cash and short-term investments   Receivables  Inventories  \
# 2019-03-31                  653134596.6594  2214000000.0  407000000.0
# 2018-12-31                     446000000.0  2694000000.0  431000000.0
# 2018-09-30                  846076999.9232  2170000000.0  381000000.0
# 2018-06-30                 1185263475.7663  2111000000.0  403000000.0
#
#            Total current assets Property, Plant & Equipment Net  \
# 2019-03-31                                        67520000000.0
# 2018-12-31                                        66503000000.0
# 2018-09-30                                        63212000000.0
# 2018-06-30                                        61446000000.0
#
#            Goodwill and Intangible Assets Long-term investments  ...  \
# 2019-03-31                 1363942775.822       5243052954.8348  ...
# 2018-12-31                            0.0       5263042042.7031  ...
# 2018-09-30                1418581418.5814       5199415968.6467  ...
# 2018-06-30               10368413105.8433       5049826362.6755  ...
#
#            Deposit Liabilities Total non-current liabilities  \
# 2019-03-31
# 2018-12-31
# 2018-09-30
# 2018-06-30
#
#            Total liabilities Other comprehensive income  \
# 2019-03-31     68050000000.0
# 2018-12-31     67605000000.0
# 2018-09-30     64240000000.0
# 2018-06-30     63267000000.0
#
#            Retained earnings (deficit) Total shareholders equity  \
# 2019-03-31                2732000000.0             25657000000.0
# 2018-12-31                2397000000.0             25358000000.0
# 2018-09-30                1880000000.0             23934000000.0
# 2018-06-30                1577000000.0             23283000000.0
#
#                 Investments          Net Debt     Other Assets  \
# 2019-03-31   -18725189.1244  43942565126.2078  1630865403.3406
# 2018-12-31   -42556313.7428  46113372881.3559     1564000000.0
# 2018-09-30   -181357104.434  42656865826.4812  1715923000.0768
# 2018-06-30  -138909859.5803  42809171221.5008  1730736524.2337
#
#            Other Liabilities
# 2019-03-31   7747300277.1328
# 2018-12-31   6508627118.6441
# 2018-09-30   5790057173.5956
# 2018-06-30   4676565302.7329
#
# [4 rows x 30 columns]

# %% [markdown]
# #### Create Dataframe for the Cash Flows

# %%
df_cash_flow = pd.DataFrame(columns=list(res_cash_flow['financials'][0].keys()))
for ratio in res_cash_flow['financials']:
    df_cash_flow = df_cash_flow.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))
df_cash_flow.head()
# Out:
#                   date Depreciation & Amortization Stock-based compensation  \
# 2019-03-31  2019-03-31                 608000000.0
# 2018-12-31  2018-12-31                 681000000.0
# 2018-09-30  2018-09-30                 564000000.0
# 2018-06-30  2018-06-30                1105000000.0
# 2018-03-31  2018-03-31                 535000000.0
#
#            Operating Cash Flow Capital Expenditure Acquisitions and disposals  \
# 2019-03-31        1949000000.0       -2186000000.0
# 2018-12-31        6676000000.0       -9914000000.0
# 2018-09-30        4516000000.0       -6713000000.0
# 2018-06-30        3217000000.0       -4151000000.0
# 2018-03-31        1412000000.0       -1738000000.0
#
#            Investment purchases and sales Investing Cash flow  \
# 2019-03-31                                      -2237000000.0
# 2018-12-31                                     -10140000000.0
# 2018-09-30                                      -7292000000.0
# 2018-06-30                                      -4478000000.0
# 2018-03-31                                      -1865000000.0
#
#            Issuance (repayment) of debt Issuance (buybacks) of shares  \
# 2019-03-31               874840835.8924                 50932514.4184
# 2018-12-31               371267150.9282                           0.0
# 2018-09-30               933681702.9125                           0.0
# 2018-06-30               834214102.3705                           0.0
# 2018-03-31
#
#            Dividend payments Financing Cash Flow  \
# 2019-03-31   -343794472.3242         721000000.0
# 2018-12-31    -335314403.111        2748000000.0
# 2018-09-30   -350418811.9573        2741000000.0
# 2018-06-30   -316321908.5007        1685000000.0
# 2018-03-31                           602000000.0
#
#            Effect of forex changes on cash Net cash flow / Change in cash  \
# 2019-03-31                      -7000000.0                    426000000.0
# 2018-12-31                      73000000.0                   -643000000.0
# 2018-09-30                      47000000.0                     12000000.0
# 2018-06-30                      57000000.0                    481000000.0
# 2018-03-31                      29000000.0                    178000000.0
#
#            Free Cash Flow Net Cash/Marketcap
# 2019-03-31                           -1.0375
# 2018-12-31                           -1.4071
# 2018-09-30                           -1.1276
# 2018-06-30                            -1.115
# 2018-03-31                            -1.115

# %% [markdown]
# #### Create DataFrame for the Enterprise Values

# %%
df_enterprise_value = pd.DataFrame(columns=list(res_enterprise_value['enterpriseValues'][0].keys()))
for ratio in res_enterprise_value['enterpriseValues']:
    df_enterprise_value = df_enterprise_value.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))
df_enterprise_value.head()
# Out:
#                   date Stock Price Number of Shares  Market Capitalization  \
# 2019-03-31  2019-03-31       45.84                                     0.0
# 2018-12-31  2018-12-31     35.2597                                     0.0
# 2018-09-30  2018-09-30     40.3076                                     0.0
# 2018-06-30  2018-06-30     40.8189                                     0.0
#
#             - Cash & Cash Equivalents  + Total Debt  Enterprise Value
# 2019-03-31               6.531346e+08  4.459570e+10      4.394257e+10
# 2018-12-31               4.460000e+08  4.655937e+10      4.611337e+10
# 2018-09-30               8.460770e+08  4.350294e+10      4.265687e+10
# 2018-06-30               1.185263e+09  4.399443e+10      4.280917e+10

# %% [markdown]
# #### Create DataFrame for Historical Discounted Cash Flow Values

# %%
df_historical_dcf = pd.DataFrame(columns=list(res_historical_dcf['historicalDCF'][0].keys()))
for ratio in res_historical_dcf['historicalDCF']:
    df_historical_dcf = df_historical_dcf.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))

df_dcf = pd.DataFrame.from_dict({res_dcf['date']: res_dcf},  orient='index')
df_historical_dcf = df_historical_dcf.append(df_dcf[['date', 'Stock Price', 'DCF']])

df_historical_dcf.head()
# Out:
#                   date  Stock Price     DCF
# 2019-03-31  2019-03-31      45.8400   0.000
# 2018-12-31  2018-12-31      35.2597   0.000
# 2018-09-30  2018-09-30      40.3076   0.000
# 2018-06-30  2018-06-30      40.8189   0.000
# 2019-10-05  2019-10-05      51.4050  51.405

# %% [markdown]
# #### Create DataFrame for Key Metrics

# %%
df_metrics = pd.DataFrame(columns=list(res_metrics['metrics'][0].keys()))
for ratio in res_metrics['metrics']:
    df_metrics = df_metrics.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))
df_metrics.head()
# Out:
#                   date Revenue per Share Net Income per Share  \
# 2019-03-31  2019-03-31
# 2018-12-31  2018-12-31
# 2018-09-30  2018-09-30
# 2018-06-30  2018-06-30
# 2018-03-31  2018-03-31
#
#            Operating Cash Flow per Share Free Cash Flow per Share  \
# 2019-03-31
# 2018-12-31
# 2018-09-30
# 2018-06-30
# 2018-03-31
#
#            Cash per Share Book Value per Share Tangible Book Value per Share  \
# 2019-03-31
# 2018-12-31
# 2018-09-30
# 2018-06-30
# 2018-03-31
#
#            Shareholders Equity per Share Interest Debt per Share  ...  \
# 2019-03-31                                                        ...
# 2018-12-31                                                        ...
# 2018-09-30                                                        ...
# 2018-06-30                                                        ...
# 2018-03-31                                                        ...
#
#            Graham Number Graham Net-Net Working Capital Tangible Asset Value  \
# 2019-03-31                      -1.4908                      7456370309.3401
# 2018-12-31                      -1.9062                      8203096338.6896
# 2018-09-30                      -1.5629                      6596480442.6343
# 2018-06-30                      -1.5065                      5936131662.3886
# 2018-03-31                      -1.5631
#
#            Net Current Asset Value Invested Capital Average Receivables  \
# 2019-03-31          -63145000000.0                         2211000000.0
# 2018-12-31          -62470000000.0
# 2018-09-30          -59127000000.0
# 2018-06-30          -57837000000.0
# 2018-03-31          -56253000000.0
#
#            Average Payables Average Inventory Capex per Share
# 2019-03-31     3822500000.0       395500000.0
# 2018-12-31
# 2018-09-30
# 2018-06-30
# 2018-03-31
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Create DataFrame for Profile

# %%
df_profile = pd.DataFrame(columns=list(res_profile['profile'].keys()))
df_profile = df_profile.append(pd.DataFrame.from_dict({res_profile['symbol']: res_profile['profile']}, orient='index'))
df_profile.head()
# Out:
#      price      beta   volAvg          mktCap  lastDiv        range  changes  \
# TRP  51.38  0.887682  1559821  34329451851.85  2.24202  34.58-46.63     0.03
#
#     changesPercentage              companyName                 exchange  \
# TRP          (+0.06%)  TransCanada Corporation  New York Stock Exchange
#
#                   industry                     website  \
# TRP  Oil & Gas - Midstream  http://www.transcanada.com
#
#                                            description                 ceo  \
# TRP  TransCanada Corp is an energy infrastructure c...  Russell K. Girling
#
#      sector                                              image
# TRP  Energy  https://financialmodelingprep.com/images-New-j...

# %% [markdown]
# ---
# ## 2. Export
# ---

# %% [markdown]
# #### Merge the DataFrames

# %%
dfs = [
    df_ratios, 
    df_debtratios, 
    df_cashFlowIndicatorRatios, 
    df_profitabilityIndicatorRatios, 
    df_operatingPerformanceRatios, 
    df_liquidityMeasurementRatios, 
    df_balance_sheet,
    df_cash_flow,
    df_enterprise_value,
    df_historical_dcf,
    df_metrics
]

# %%
df_agg = None
for df in dfs:
    if df_agg is None:
        df_agg = df
    else:
        df_agg = df_agg.merge(df, left_index=True, right_index=True, how='outer')
df_agg.shape
# Out:
# (15, 164)

# %%
df_agg.T
# Out:
#                                             2009-12-31         2010-12-31  \
# priceBookValueRatio
# priceToBookRatio
# priceToSalesRatio                               2.5899             3.7993
# priceEarningsRatio                             17.0706            21.1875
# receivablesTurnover_x                           7.9214             6.2576
# priceToFreeCashFlowsRatio                          0.0                0.0
# priceToOperatingCashFlowsRatio                  6.7495             6.7495
# priceCashFlowRatio                                   0                  0
# priceEarningsToGrowthRatio                           0                  0
# priceSalesRatio                                      0                  0
# dividendYield
# enterpriseValueMultiple                4.5583853916387    5.5524673851389
# priceFairValue                                       0                  0
# debtRatio                                       0.4642             0.4673
# debtEquityRatio                                 1.3954             1.3072
# longtermDebtToCapitalization          0.55205773955774   0.52936045693706
# totalDebtToCapitalization             0.58253427598248   0.56656820066335
# interestCoverage                                2.7358             3.3752
# cashFlowToDebtRatio                    0.1469143081761   0.13153441573291
# companyEquityMultiplier                 3.005896468975    2.7975130029294
# operatingCashFlowPerShare                        5.083             4.1496
# freeCashFlowPerShare                           -4.1259            -2.1643
# cashPerShare                                    1.6949             1.1023
# payoutRatio                                     0.6527             0.8877
# receivablesTurnover_y                           7.9214             6.2576
# operatingCashFlowSalesRatio            0.3654809925437   0.41973146526562
# freeCashFlowOperatingCashFlowRatio   -0.81170568561873  -0.52155771905425
# cashFlowCoverageRatios                 0.1469143081761   0.13153441573291
# shortTermCoverageRatios                1.2578880942364   0.94264175680106
# capitalExpenditureCoverageRatios      0.55196603285951   0.65722120658137
# ...                                                ...                ...
# Enterprise Value over EBITDA                       NaN                NaN
# EV to Operating cash flow                          NaN                NaN
# EV to Free cash flow                               NaN                NaN
# Earnings Yield                                     NaN                NaN
# Free Cash Flow Yield                               NaN                NaN
# Debt to Equity                                     NaN                NaN
# Debt to Assets                                     NaN                NaN
# Net Debt to EBITDA                                 NaN                NaN
# Current ratio                                      NaN                NaN
# Interest Coverage                                  NaN                NaN
# Income Quality                                     NaN                NaN
# Dividend Yield                                     NaN                NaN
# Payout Ratio                                       NaN                NaN
# SG&A to Revenue                                    NaN                NaN
# R&D to Revenue                                     NaN                NaN
# Intangibles to Total Assets                        NaN                NaN
# Capex to Operating Cash Flow                       NaN                NaN
# Capex to Revenue                                   NaN                NaN
# Capex to Depreciation                              NaN                NaN
# Stock-based compensation to Revenue                NaN                NaN
# Graham Number                                      NaN                NaN
# Graham Net-Net                                     NaN                NaN
# Working Capital                                    NaN                NaN
# Tangible Asset Value                               NaN                NaN
# Net Current Asset Value                            NaN                NaN
# Invested Capital                                   NaN                NaN
# Average Receivables                                NaN                NaN
# Average Payables                                   NaN                NaN
# Average Inventory                                  NaN                NaN
# Capex per Share                                    NaN                NaN
#
#                                            2011-12-31        2012-12-31  \
# priceBookValueRatio
# priceToBookRatio
# priceToSalesRatio                              3.8688            4.1597
# priceEarningsRatio                            20.5152           25.5632
# receivablesTurnover_x                           6.541             7.568
# priceToFreeCashFlowsRatio                     26.0692           34.2863
# priceToOperatingCashFlowsRatio                 6.7495            6.7495
# priceCashFlowRatio                                  0                 0
# priceEarningsToGrowthRatio                          0                 0
# priceSalesRatio                                     0                 0
# dividendYield
# enterpriseValueMultiple               4.3867903189324   4.6904818988253
# priceFairValue                                      0                 0
# debtRatio                                       0.455            0.4583
# debtEquityRatio                                1.2825            1.3117
# longtermDebtToCapitalization         0.52738222547419  0.52925620754927
# totalDebtToCapitalization            0.56188041323176  0.56741616146113
# interestCoverage                                3.301            2.8648
# cashFlowToDebtRatio                  0.17113938155818   0.1609863853575
# companyEquityMultiplier               2.8187447898059   2.8618059251375
# operatingCashFlowPerShare                      5.3661             5.035
# freeCashFlowPerShare                           1.7077            1.3719
# cashPerShare                                   0.9521            0.7769
# payoutRatio                                     0.773            0.9588
# receivablesTurnover_y                           6.541             7.568
# operatingCashFlowSalesRatio          0.47021303737722  0.44598476333209
# freeCashFlowOperatingCashFlowRatio   0.31823114487248   0.2724726967236
# cashFlowCoverageRatios               0.17113938155818   0.1609863853575
# shortTermCoverageRatios               1.3173695496784   1.1268538971285
# capitalExpenditureCoverageRatios      1.4667727815361   1.3745188606621
# ...                                               ...               ...
# Enterprise Value over EBITDA                      NaN               NaN
# EV to Operating cash flow                         NaN               NaN
# EV to Free cash flow                              NaN               NaN
# Earnings Yield                                    NaN               NaN
# Free Cash Flow Yield                              NaN               NaN
# Debt to Equity                                    NaN               NaN
# Debt to Assets                                    NaN               NaN
# Net Debt to EBITDA                                NaN               NaN
# Current ratio                                     NaN               NaN
# Interest Coverage                                 NaN               NaN
# Income Quality                                    NaN               NaN
# Dividend Yield                                    NaN               NaN
# Payout Ratio                                      NaN               NaN
# SG&A to Revenue                                   NaN               NaN
# R&D to Revenue                                    NaN               NaN
# Intangibles to Total Assets                       NaN               NaN
# Capex to Operating Cash Flow                      NaN               NaN
# Capex to Revenue                                  NaN               NaN
# Capex to Depreciation                             NaN               NaN
# Stock-based compensation to Revenue               NaN               NaN
# Graham Number                                     NaN               NaN
# Graham Net-Net                                    NaN               NaN
# Working Capital                                   NaN               NaN
# Tangible Asset Value                              NaN               NaN
# Net Current Asset Value                           NaN               NaN
# Invested Capital                                  NaN               NaN
# Average Receivables                               NaN               NaN
# Average Payables                                  NaN               NaN
# Average Inventory                                 NaN               NaN
# Capex per Share                                   NaN               NaN
#
#                                             2013-12-31          2014-12-31  \
# priceBookValueRatio
# priceToBookRatio
# priceToSalesRatio                               3.6616              3.4104
# priceEarningsRatio                             20.0756             23.1932
# receivablesTurnover_x                           7.8262              8.0249
# priceToFreeCashFlowsRatio                          0.0                 0.0
# priceToOperatingCashFlowsRatio                  6.7495              6.7495
# priceCashFlowRatio                                   0     6.7538609559868
# priceEarningsToGrowthRatio                           0      15.51185673913
# priceSalesRatio                                      0     2.8023383799706
# dividendYield                                            0.047123840373381
# enterpriseValueMultiple                4.9069241832751     9.6990540875912
# priceFairValue                                       0      1.496686754064
# debtRatio                                       0.4781               0.485
# debtEquityRatio                                 1.3911              1.4884
# longtermDebtToCapitalization          0.55339922854388    0.55846260708497
# totalDebtToCapitalization             0.58178123941754    0.59813714333881
# interestCoverage                                3.4335              3.2295
# cashFlowToDebtRatio                   0.14256887854094    0.14888669673055
# companyEquityMultiplier                2.9094736842105     3.0689564761405
# operatingCashFlowPerShare                       5.5295              6.9358
# freeCashFlowPerShare                           -1.6224             -0.1822
# cashPerShare                                    1.3952              0.8026
# payoutRatio                                     0.7293              0.7014
# receivablesTurnover_y                           7.8262              8.0249
# operatingCashFlowSalesRatio           0.41764237808344    0.41492390770741
# freeCashFlowOperatingCashFlowRatio   -0.29341317365268  -0.026265972550865
# cashFlowCoverageRatios                0.14256887854094    0.14888669673055
# shortTermCoverageRatios                1.3051509769094    0.99108818011257
# capitalExpenditureCoverageRatios      0.77314814814816    0.97440627161634
# ...                                                ...                 ...
# Enterprise Value over EBITDA                       NaN                 NaN
# EV to Operating cash flow                          NaN                 NaN
# EV to Free cash flow                               NaN                 NaN
# Earnings Yield                                     NaN                 NaN
# Free Cash Flow Yield                               NaN                 NaN
# Debt to Equity                                     NaN                 NaN
# Debt to Assets                                     NaN                 NaN
# Net Debt to EBITDA                                 NaN                 NaN
# Current ratio                                      NaN                 NaN
# Interest Coverage                                  NaN                 NaN
# Income Quality                                     NaN                 NaN
# Dividend Yield                                     NaN                 NaN
# Payout Ratio                                       NaN                 NaN
# SG&A to Revenue                                    NaN                 NaN
# R&D to Revenue                                     NaN                 NaN
# Intangibles to Total Assets                        NaN                 NaN
# Capex to Operating Cash Flow                       NaN                 NaN
# Capex to Revenue                                   NaN                 NaN
# Capex to Depreciation                              NaN                 NaN
# Stock-based compensation to Revenue                NaN                 NaN
# Graham Number                                      NaN                 NaN
# Graham Net-Net                                     NaN                 NaN
# Working Capital                                    NaN                 NaN
# Tangible Asset Value                               NaN                 NaN
# Net Current Asset Value                            NaN                 NaN
# Invested Capital                                   NaN                 NaN
# Average Receivables                                NaN                 NaN
# Average Payables                                   NaN                 NaN
# Average Inventory                                  NaN                 NaN
# Capex per Share                                    NaN                 NaN
#
#                                              2015-12-31          2016-12-31  \
# priceBookValueRatio
# priceToBookRatio
# priceToSalesRatio                                2.0343              2.5267
# priceEarningsRatio                                  0.0            379.1597
# receivablesTurnover_x                            7.6977              7.3312
# priceToFreeCashFlowsRatio                           0.0                 0.0
# priceToOperatingCashFlowsRatio                   6.7495              6.7495
# priceCashFlowRatio                      4.5163008895987     6.0244745314653
# priceEarningsToGrowthRatio                                   131.0646412017
# priceSalesRatio                         1.7439851228751      2.433893472543
# dividendYield                         0.073032283385499   0.047023286160533
# enterpriseValueMultiple                 25.688315916956     16.319562450243
# priceFairValue                          1.2044934359412     1.2589380962196
# debtRatio                                        0.5448              0.5094
# debtEquityRatio                                  2.1343              1.8492
# longtermDebtToCapitalization           0.65579194237373    0.63523308270677
# totalDebtToCapitalization              0.68094563381922    0.64901898367867
# interestCoverage                                 0.1883              1.2928
# cashFlowToDebtRatio                    0.12496080722857    0.11300858321257
# companyEquityMultiplier                 3.9176298819808     3.6299212598425
# operatingCashFlowPerShare                        8.5512              8.9765
# freeCashFlowPerShare                            -0.0878             -0.4126
# cashPerShare                                      1.658              1.7992
# payoutRatio                                     -0.9154             10.6659
# receivablesTurnover_y                            7.6977              7.3312
# operatingCashFlowSalesRatio            0.38615343961948    0.40400095640392
# freeCashFlowOperatingCashFlowRatio   -0.010264598540131  -0.045965673702901
# cashFlowCoverageRatios                 0.12496080722857    0.11300858321257
# shortTermCoverageRatios                 1.1644090305445     1.9406584992343
# capitalExpenditureCoverageRatios       0.98983969293293    0.95605431912486
# ...                                                 ...                 ...
# Enterprise Value over EBITDA                        NaN                 NaN
# EV to Operating cash flow                           NaN                 NaN
# EV to Free cash flow                                NaN                 NaN
# Earnings Yield                                      NaN                 NaN
# Free Cash Flow Yield                                NaN                 NaN
# Debt to Equity                                      NaN                 NaN
# Debt to Assets                                      NaN                 NaN
# Net Debt to EBITDA                                  NaN                 NaN
# Current ratio                                       NaN                 NaN
# Interest Coverage                                   NaN                 NaN
# Income Quality                                      NaN                 NaN
# Dividend Yield                                      NaN                 NaN
# Payout Ratio                                        NaN                 NaN
# SG&A to Revenue                                     NaN                 NaN
# R&D to Revenue                                      NaN                 NaN
# Intangibles to Total Assets                         NaN                 NaN
# Capex to Operating Cash Flow                        NaN                 NaN
# Capex to Revenue                                    NaN                 NaN
# Capex to Depreciation                               NaN                 NaN
# Stock-based compensation to Revenue                 NaN                 NaN
# Graham Number                                       NaN                 NaN
# Graham Net-Net                                      NaN                 NaN
# Working Capital                                     NaN                 NaN
# Tangible Asset Value                                NaN                 NaN
# Net Current Asset Value                             NaN                 NaN
# Invested Capital                                    NaN                 NaN
# Average Receivables                                 NaN                 NaN
# Average Payables                                    NaN                 NaN
# Average Inventory                                   NaN                 NaN
# Capex per Share                                     NaN                 NaN
#
#                                             2017-12-31      2018-03-31  \
# priceBookValueRatio                                                NaN
# priceToBookRatio                                                   NaN
# priceToSalesRatio                               3.1682             NaN
# priceEarningsRatio                             18.2548             NaN
# receivablesTurnover_x                           5.9941             NaN
# priceToFreeCashFlowsRatio                          0.0             NaN
# priceToOperatingCashFlowsRatio                  6.7495             NaN
# priceCashFlowRatio                     7.6764844359461             NaN
# priceEarningsToGrowthRatio             12.717140829901             NaN
# priceSalesRatio                        2.9852043720721             NaN
# dividendYield                        0.033351587785654             NaN
# enterpriseValueMultiple                11.140018576196             NaN
# priceFairValue                         1.6034192100323             NaN
# debtRatio                                       0.5053             NaN
# debtEquityRatio                                 1.7377             NaN
# longtermDebtToCapitalization          0.60828209821498             NaN
# totalDebtToCapitalization             0.63473377097009             NaN
# interestCoverage                                2.4828             NaN
# cashFlowToDebtRatio                   0.12019948978419             NaN
# companyEquityMultiplier                3.4386756659611             NaN
# operatingCashFlowPerShare                       7.6355             NaN
# freeCashFlowPerShare                           -2.4308             NaN
# cashPerShare                                    1.5899             NaN
# payoutRatio                                      0.564             NaN
# receivablesTurnover_y                           5.9941             NaN
# operatingCashFlowSalesRatio           0.38887649639378             NaN
# freeCashFlowOperatingCashFlowRatio   -0.31835564053537             NaN
# cashFlowCoverageRatios                0.12019948978419             NaN
# shortTermCoverageRatios                1.1298336573774             NaN
# capitalExpenditureCoverageRatios      0.75852066715011             NaN
# ...                                                ...             ...
# Enterprise Value over EBITDA                       NaN
# EV to Operating cash flow                          NaN
# EV to Free cash flow                               NaN
# Earnings Yield                                     NaN          0.0669
# Free Cash Flow Yield                               NaN         -0.0653
# Debt to Equity                                     NaN
# Debt to Assets                                     NaN
# Net Debt to EBITDA                                 NaN
# Current ratio                                      NaN
# Interest Coverage                                  NaN
# Income Quality                                     NaN          1.9237
# Dividend Yield                                     NaN          0.0377
# Payout Ratio                                       NaN
# SG&A to Revenue                                    NaN
# R&D to Revenue                                     NaN
# Intangibles to Total Assets                        NaN
# Capex to Operating Cash Flow                       NaN          1.2309
# Capex to Revenue                                   NaN          0.5076
# Capex to Depreciation                              NaN         -3.2486
# Stock-based compensation to Revenue                NaN
# Graham Number                                      NaN
# Graham Net-Net                                     NaN         -1.5631
# Working Capital                                    NaN
# Tangible Asset Value                               NaN
# Net Current Asset Value                            NaN  -56253000000.0
# Invested Capital                                   NaN
# Average Receivables                                NaN
# Average Payables                                   NaN
# Average Inventory                                  NaN
# Capex per Share                                    NaN
#
#                                           2018-06-30       2018-09-30  \
# priceBookValueRatio                              NaN              NaN
# priceToBookRatio                                 NaN              NaN
# priceToSalesRatio                                NaN              NaN
# priceEarningsRatio                               NaN              NaN
# receivablesTurnover_x                            NaN              NaN
# priceToFreeCashFlowsRatio                        NaN              NaN
# priceToOperatingCashFlowsRatio                   NaN              NaN
# priceCashFlowRatio                               NaN              NaN
# priceEarningsToGrowthRatio                       NaN              NaN
# priceSalesRatio                                  NaN              NaN
# dividendYield                                    NaN              NaN
# enterpriseValueMultiple                          NaN              NaN
# priceFairValue                                   NaN              NaN
# debtRatio                                        NaN              NaN
# debtEquityRatio                                  NaN              NaN
# longtermDebtToCapitalization                     NaN              NaN
# totalDebtToCapitalization                        NaN              NaN
# interestCoverage                                 NaN              NaN
# cashFlowToDebtRatio                              NaN              NaN
# companyEquityMultiplier                          NaN              NaN
# operatingCashFlowPerShare                        NaN              NaN
# freeCashFlowPerShare                             NaN              NaN
# cashPerShare                                     NaN              NaN
# payoutRatio                                      NaN              NaN
# receivablesTurnover_y                            NaN              NaN
# operatingCashFlowSalesRatio                      NaN              NaN
# freeCashFlowOperatingCashFlowRatio               NaN              NaN
# cashFlowCoverageRatios                           NaN              NaN
# shortTermCoverageRatios                          NaN              NaN
# capitalExpenditureCoverageRatios                 NaN              NaN
# ...                                              ...              ...
# Enterprise Value over EBITDA
# EV to Operating cash flow
# EV to Free cash flow
# Earnings Yield                                0.0636           0.0813
# Free Cash Flow Yield                         -0.0653          -0.0653
# Debt to Equity
# Debt to Assets
# Net Debt to EBITDA
# Current ratio
# Interest Coverage                            -2.3781          -2.1889
# Income Quality                                4.0981           4.8664
# Dividend Yield                                0.0435           0.0435
# Payout Ratio
# SG&A to Revenue
# R&D to Revenue
# Intangibles to Total Assets                    0.112           0.0151
# Capex to Operating Cash Flow                  1.2903           1.4865
# Capex to Revenue                              1.2992           2.1271
# Capex to Depreciation                        -3.7566         -11.9025
# Stock-based compensation to Revenue
# Graham Number
# Graham Net-Net                               -1.5065          -1.5629
# Working Capital
# Tangible Asset Value                 5936131662.3886  6596480442.6343
# Net Current Asset Value               -57837000000.0   -59127000000.0
# Invested Capital
# Average Receivables
# Average Payables
# Average Inventory
# Capex per Share
#
#                                             2018-12-31       2019-03-31  \
# priceBookValueRatio                                                 NaN
# priceToBookRatio                                                    NaN
# priceToSalesRatio                               2.3002              NaN
# priceEarningsRatio                             12.2947              NaN
# receivablesTurnover_x                           5.2515              NaN
# priceToFreeCashFlowsRatio                          0.0              NaN
# priceToOperatingCashFlowsRatio                  6.7495              NaN
# priceCashFlowRatio                     4.8519068497326              NaN
# priceEarningsToGrowthRatio             8.5910992436515              NaN
# priceSalesRatio                        2.3250419913735              NaN
# dividendYield                        0.049395914999966              NaN
# enterpriseValueMultiple                8.7172533318092              NaN
# priceFairValue                         1.0840633103824              NaN
# debtRatio                                       0.5079              NaN
# debtEquityRatio                                 1.7125              NaN
# longtermDebtToCapitalization           0.6000545293436              NaN
# totalDebtToCapitalization             0.63133489991078              NaN
# interestCoverage                                2.8252              NaN
# cashFlowToDebtRatio                   0.13047112915746              NaN
# companyEquityMultiplier                3.3717363146772              NaN
# operatingCashFlowPerShare                       9.8112              NaN
# freeCashFlowPerShare                           -4.3241              NaN
# cashPerShare                                    0.6676              NaN
# payoutRatio                                     0.5348              NaN
# receivablesTurnover_y                           5.2515              NaN
# operatingCashFlowSalesRatio           0.47920169603042              NaN
# freeCashFlowOperatingCashFlowRatio   -0.44073226544622              NaN
# cashFlowCoverageRatios                0.13047112915746              NaN
# shortTermCoverageRatios                1.0531812339332              NaN
# capitalExpenditureCoverageRatios       0.6940914866582              NaN
# ...                                                ...              ...
# Enterprise Value over EBITDA
# EV to Operating cash flow
# EV to Free cash flow
# Earnings Yield                                  0.0813           0.0633
# Free Cash Flow Yield                           -0.0653          -0.0505
# Debt to Equity
# Debt to Assets
# Net Debt to EBITDA
# Current ratio
# Interest Coverage                               -3.058          -2.5785
# Income Quality                                  7.2173           1.9412
# Dividend Yield                                  0.0435           0.0339
# Payout Ratio
# SG&A to Revenue
# R&D to Revenue
# Intangibles to Total Assets                        0.0           0.0137
# Capex to Operating Cash Flow                     1.485           1.1216
# Capex to Revenue                                2.5394           0.6269
# Capex to Depreciation                          -14.558          -3.5954
# Stock-based compensation to Revenue
# Graham Number
# Graham Net-Net                                 -1.9062          -1.4908
# Working Capital
# Tangible Asset Value                   8203096338.6896  7456370309.3401
# Net Current Asset Value                 -62470000000.0   -63145000000.0
# Invested Capital
# Average Receivables                                        2211000000.0
# Average Payables                                           3822500000.0
# Average Inventory                                           395500000.0
# Capex per Share
#
#                                     2019-10-05
# priceBookValueRatio                        NaN
# priceToBookRatio                           NaN
# priceToSalesRatio                          NaN
# priceEarningsRatio                         NaN
# receivablesTurnover_x                      NaN
# priceToFreeCashFlowsRatio                  NaN
# priceToOperatingCashFlowsRatio             NaN
# priceCashFlowRatio                         NaN
# priceEarningsToGrowthRatio                 NaN
# priceSalesRatio                            NaN
# dividendYield                              NaN
# enterpriseValueMultiple                    NaN
# priceFairValue                             NaN
# debtRatio                                  NaN
# debtEquityRatio                            NaN
# longtermDebtToCapitalization               NaN
# totalDebtToCapitalization                  NaN
# interestCoverage                           NaN
# cashFlowToDebtRatio                        NaN
# companyEquityMultiplier                    NaN
# operatingCashFlowPerShare                  NaN
# freeCashFlowPerShare                       NaN
# cashPerShare                               NaN
# payoutRatio                                NaN
# receivablesTurnover_y                      NaN
# operatingCashFlowSalesRatio                NaN
# freeCashFlowOperatingCashFlowRatio         NaN
# cashFlowCoverageRatios                     NaN
# shortTermCoverageRatios                    NaN
# capitalExpenditureCoverageRatios           NaN
# ...                                        ...
# Enterprise Value over EBITDA               NaN
# EV to Operating cash flow                  NaN
# EV to Free cash flow                       NaN
# Earnings Yield                             NaN
# Free Cash Flow Yield                       NaN
# Debt to Equity                             NaN
# Debt to Assets                             NaN
# Net Debt to EBITDA                         NaN
# Current ratio                              NaN
# Interest Coverage                          NaN
# Income Quality                             NaN
# Dividend Yield                             NaN
# Payout Ratio                               NaN
# SG&A to Revenue                            NaN
# R&D to Revenue                             NaN
# Intangibles to Total Assets                NaN
# Capex to Operating Cash Flow               NaN
# Capex to Revenue                           NaN
# Capex to Depreciation                      NaN
# Stock-based compensation to Revenue        NaN
# Graham Number                              NaN
# Graham Net-Net                             NaN
# Working Capital                            NaN
# Tangible Asset Value                       NaN
# Net Current Asset Value                    NaN
# Invested Capital                           NaN
# Average Receivables                        NaN
# Average Payables                           NaN
# Average Inventory                          NaN
# Capex per Share                            NaN
#
# [164 rows x 15 columns]

# %%
df_profile.reset_index().to_csv('../data/raw/' + '.'.join(tickers) + '.profile.csv')

# %%
df_agg.reset_index().to_csv('../data/raw/' + '.'.join(tickers) + '.csv')
