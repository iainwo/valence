# %% [markdown]
# ---
# # Data Ingestion
# ---
# Notebook: 0.1.0-iw-data-ingestion.ipynb<br>
# Dependencies: requirements.txt<br>
# Date: 2019-OCT-3<br>
# Abstract:
# ```
#     The goal of this notebook is ingest stock data from the Financial Modelling Prep API and form a dataframe. This dataframe will be exported to the raw unprocessed directory.
# ```

# %% [markdown]
# ---
# ## 0. Setup
# ---

# %%
import pandas as pd

import fmpclient
from fmpclient import FMPClient
api = FMPClient()
fmpclient.__version__
# Out:
# '0.1.3'

# %% [markdown]
# ---
# ## 1. Pull data from API
# ---

# %%
tickers = ['MSFT']

# %%
res_income_statements = api.company_valuation.income_statement(tickers, period='quarter')
res_financial_ratios  = api.company_valuation.financial_ratios(tickers)
res_balance_sheet     = api.company_valuation.balance_sheet_statement(tickers, period='quarter')
res_cash_flow         = api.company_valuation.cash_flow_statement(tickers, period='quarter')
res_enterprise_value  = api.company_valuation.enterprise_value(tickers, period='quarter')
res_historical_dcf    = api.company_valuation.historical_discounted_cash_flow_value(tickers, period='quarter')
res_dcf               = api.company_valuation.discounted_cash_flow_value(tickers)
res_metrics           = api.company_valuation.key_metrics(tickers, period='quarter')
res_profile           = api.company_valuation.profile(tickers)
# Out:
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financials/income-statement/MSFT, path: financials/income-statement/MSFT
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financial-ratios/MSFT, path: financial-ratios/MSFT
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/MSFT, path: financials/balance-sheet-statement/MSFT
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/financials/cash-flow-statement/MSFT, path: financials/cash-flow-statement/MSFT
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/enterprise-value/MSFT, path: enterprise-value/MSFT
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/company/historical-discounted-cash-flow/MSFT, path: company/historical-discounted-cash-flow/MSFT
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/company/discounted-cash-flow/MSFT, path: company/discounted-cash-flow/MSFT
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/company-key-metrics/MSFT, path: company-key-metrics/MSFT
# url: https://financialmodelingprep.com/api/v3/, request_url: https://financialmodelingprep.com/api/v3/company/profile/MSFT, path: company/profile/MSFT

# %% [markdown]
# #### Create Dataframe for the Income Statements

# %%
df_income_statements = pd.DataFrame(columns=list(res_income_statements['financials'][0].keys()))
for income_statement in res_income_statements['financials']:
    df_income_statements = df_income_statements.append(pd.DataFrame.from_dict({income_statement['date']: income_statement}, orient='index'))
df_income_statements.head()
# Out:
#                   date        Revenue Revenue Growth Cost of Revenue  \
# 2019-06-30  2019-06-30  33717000000.0         0.1207   10412000000.0
# 2019-03-31  2019-03-31  30571000000.0         0.1399   10170000000.0
# 2018-12-31  2018-12-31  32471000000.0         0.1229   12423000000.0
# 2018-09-30  2018-09-30  29084000000.0         0.1853    9905000000.0
# 2018-06-30  2018-06-30  30085000000.0          0.175    9742000000.0
#
#              Gross Profit  R&D Expenses  SG&A Expense Operating Expenses  \
# 2019-06-30  23305000000.0  4513000000.0  6387000000.0      10900000000.0
# 2019-03-31  20401000000.0  4316000000.0  5744000000.0      10060000000.0
# 2018-12-31  20048000000.0  4070000000.0  5720000000.0       9790000000.0
# 2018-09-30  19179000000.0  3977000000.0  5247000000.0       9224000000.0
# 2018-06-30  20343000000.0  3933000000.0  6031000000.0       9964000000.0
#
#            Operating Income Interest Expense  ... Gross Margin EBITDA Margin  \
# 2019-06-30    12405000000.0              0.0  ...       0.6912          0.46
# 2019-03-31    10341000000.0              0.0  ...       0.6673         0.439
# 2018-12-31    10258000000.0              0.0  ...       0.6174         0.412
# 2018-09-30     9955000000.0              0.0  ...       0.6594         0.449
# 2018-06-30    10379000000.0              0.0  ...       0.6762         0.439
#
#            EBIT Margin Profit Margin Free Cash Flow margin         EBITDA  \
# 2019-06-30      0.3736         0.391                0.3576  15520000000.0
# 2019-03-31       0.343         0.288                0.3583  13412000000.0
# 2018-12-31      0.3198         0.259                0.1599  13380000000.0
# 2018-09-30      0.3514         0.303                0.3457  13058000000.0
# 2018-06-30       0.355         0.295                0.2472  13196000000.0
#
#                      EBIT Consolidated Income Earnings Before Tax Margin  \
# 2019-06-30  12596000000.0       13187000000.0                     0.3736
# 2019-03-31  10486000000.0        8809000000.0                      0.343
# 2018-12-31  10385000000.0        8420000000.0                     0.3198
# 2018-09-30  10221000000.0        8824000000.0                     0.3514
# 2018-06-30  10680000000.0        8873000000.0                      0.355
#
#            Net Profit Margin
# 2019-06-30            0.3911
# 2019-03-31            0.2881
# 2018-12-31            0.2593
# 2018-09-30            0.3034
# 2018-06-30            0.2949
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Create Dataframe for the Financial Ratios

# %%
df_ratios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['investmentValuationRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_ratios = df_ratios.append(pd.DataFrame.from_dict({ratio['date']: ratio['investmentValuationRatios']}, orient='index'))

df_debtratios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['debtRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_debtratios = df_debtratios.append(pd.DataFrame.from_dict({ratio['date']: ratio['debtRatios']}, orient='index'))

df_cashFlowIndicatorRatios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['cashFlowIndicatorRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_cashFlowIndicatorRatios = df_cashFlowIndicatorRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['cashFlowIndicatorRatios']}, orient='index'))

df_profitabilityIndicatorRatios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['profitabilityIndicatorRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_profitabilityIndicatorRatios = df_profitabilityIndicatorRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['profitabilityIndicatorRatios']}, orient='index'))
    
df_operatingPerformanceRatios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['operatingPerformanceRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_operatingPerformanceRatios = df_operatingPerformanceRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['operatingPerformanceRatios']}, orient='index'))
    
df_liquidityMeasurementRatios = pd.DataFrame(columns=list(res_financial_ratios['ratios'][0]['liquidityMeasurementRatios'].keys()))
for ratio in res_financial_ratios['ratios']:
    df_liquidityMeasurementRatios = df_liquidityMeasurementRatios.append(pd.DataFrame.from_dict({ratio['date']: ratio['liquidityMeasurementRatios']}, orient='index'))

# %%
df_ratios.head(1)
# Out:
#            priceBookValueRatio priceToBookRatio priceToSalesRatio  \
# 2019-06-30             10.1498           4.3865            8.2618
#
#            priceEarningsRatio receivablesTurnover priceToFreeCashFlowsRatio  \
# 2019-06-30            26.5519               4.494                   27.2105
#
#            priceToOperatingCashFlowsRatio priceCashFlowRatio  \
# 2019-06-30                        19.9232                  0
#
#            priceEarningsToGrowthRatio priceSalesRatio dividendYield  \
# 2019-06-30                          0               0
#
#            enterpriseValueMultiple priceFairValue
# 2019-06-30         3.7325085786527              0

# %%
df_debtratios.head(1)
# Out:
#            debtRatio debtEquityRatio longtermDebtToCapitalization  \
# 2019-06-30    0.2735          0.7658             0.41585797465464
#
#            totalDebtToCapitalization interestCoverage cashFlowToDebtRatio  \
# 2019-06-30          0.43368973303228              0.0    0.66591378914325
#
#            companyEquityMultiplier
# 2019-06-30         2.8003127137692

# %%
df_cashFlowIndicatorRatios.head(1)
# Out:
#            operatingCashFlowPerShare freeCashFlowPerShare cashPerShare  \
# 2019-06-30                    6.8011                4.189      17.4402
#
#            payoutRatio receivablesTurnover operatingCashFlowSalesRatio  \
# 2019-06-30       0.352               4.494            0.41468337531686
#
#            freeCashFlowOperatingCashFlowRatio cashFlowCoverageRatios  \
# 2019-06-30                    0.7331608699818       0.66591378914325
#
#            shortTermCoverageRatios capitalExpenditureCoverageRatios  \
# 2019-06-30         9.4606598984772                  3.7475763016158
#
#            dividendpaidAndCapexCoverageRatios dividendPayoutRatio
# 2019-06-30                    1.8814897605999     0.3519622833843

# %%
df_profitabilityIndicatorRatios.head(1)
# Out:
#                    niperEBT ebtperEBIT    ebitperRevenue grossProfitMargin  \
# 2019-06-30  0.8981871452115          1  0.34716273451841  0.65901957200639
#
#            operatingProfitMargin pretaxProfitMargin   netProfitMargin  \
# 2019-06-30                     1   0.34136980205494  0.31181710544091
#
#            effectiveTaxRate returnOnAssets returnOnEquity  \
# 2019-06-30  0.1018128547885         0.2616         0.3835
#
#            returnOnCapitalEmployed         nIperEBT eBTperEBIT  \
# 2019-06-30                  0.3022  0.8981871452115          1
#
#               eBITperRevenue
# 2019-06-30  0.34716273451841

# %%
df_operatingPerformanceRatios.head(1)
# Out:
#            receivablesTurnover payablesTurnover inventoryTurnover  \
# 2019-06-30               4.494           3.7465           53.2669
#
#            fixedAssetTurnover     assetTurnover
# 2019-06-30    2.8694591390004  0.43915674423149

# %%
df_liquidityMeasurementRatios.head(1)
# Out:
#            currentRatio       quickRatio        cashRatio  \
# 2019-06-30        2.529  2.3529674445405  1.9276721405935
#
#            daysOfSalesOutstanding daysOfInventoryOutstanding operatingCycle  \
# 2019-06-30               -17.5482                    85.6326
#
#            daysOfPayablesOutstanding cashConversionCycle
# 2019-06-30                   27.2119

# %% [markdown]
# #### Create DataFrame for Balance Sheet

# %%
df_balance_sheet = pd.DataFrame(columns=list(res_balance_sheet['financials'][0].keys()))
for ratio in res_balance_sheet['financials']:
    df_balance_sheet = df_balance_sheet.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))
df_balance_sheet.head()
# Out:
#                   date Cash and cash equivalents Short-term investments  \
# 2019-06-30  2019-06-30            133819000000.0                    0.0
# 2019-03-31  2019-03-31            131618000000.0                    0.0
# 2018-12-31  2018-12-31            127662000000.0                    0.0
# 2018-09-30  2018-09-30            135880000000.0                    0.0
# 2018-06-30  2018-06-30            133768000000.0                    0.0
#
#            Cash and short-term investments    Receivables   Inventories  \
# 2019-06-30                  133819000000.0  29524000000.0  2063000000.0
# 2019-03-31                  131618000000.0  19269000000.0  1951000000.0
# 2018-12-31                  127662000000.0  19680000000.0  1961000000.0
# 2018-09-30                  135880000000.0  17390000000.0  3614000000.0
# 2018-06-30                  133768000000.0  26481000000.0  2662000000.0
#
#            Total current assets Property, Plant & Equipment Net  \
# 2019-06-30       111004000000.0                   43856000000.0
# 2019-03-31       103394000000.0                   40769000000.0
# 2018-12-31       101985000000.0                   39523000000.0
# 2018-09-30        93424000000.0                   38164000000.0
# 2018-06-30        89186000000.0                   36146000000.0
#
#            Goodwill and Intangible Assets Long-term investments  ...  \
# 2019-06-30                  49776000000.0          2649000000.0  ...
# 2019-03-31                  49964000000.0          2403000000.0  ...
# 2018-12-31                  50059000000.0          2274000000.0  ...
# 2018-09-30                  43434000000.0          2034000000.0  ...
# 2018-06-30                  43736000000.0          1862000000.0  ...
#
#            Deposit Liabilities Total non-current liabilities  \
# 2019-06-30                 0.0                114806000000.0
# 2019-03-31                 0.0                114556000000.0
# 2018-12-31                 0.0                116413000000.0
# 2018-09-30                 0.0                115375000000.0
# 2018-06-30                 0.0                117642000000.0
#
#            Total liabilities Other comprehensive income  \
# 2019-06-30    184226000000.0               -340000000.0
# 2019-03-31    168417000000.0              -1265000000.0
# 2018-12-31    166731000000.0              -2013000000.0
# 2018-09-30    171652000000.0              -2615000000.0
# 2018-06-30    176130000000.0              -2187000000.0
#
#            Retained earnings (deficit) Total shareholders equity  \
# 2019-06-30               24150000000.0            102330000000.0
# 2019-03-31               18338000000.0             94864000000.0
# 2018-12-31               16585000000.0             92128000000.0
# 2018-09-30               17279000000.0             85967000000.0
# 2018-06-30               13682000000.0             82718000000.0
#
#              Investments        Net Debt   Other Assets Other Liabilities
# 2019-06-30  2649000000.0  -55453000000.0  10146000000.0     54522000000.0
# 2019-03-31  2403000000.0  -52546000000.0   7049000000.0     39802000000.0
# 2018-12-31  2274000000.0  -48810000000.0   7571000000.0     39239000000.0
# 2018-09-30  2034000000.0  -53998000000.0   7311000000.0     41269000000.0
# 2018-06-30  1862000000.0  -51960000000.0   6751000000.0     45873000000.0
#
# [5 rows x 30 columns]

# %% [markdown]
# #### Create Dataframe for the Cash Flows

# %%
df_cash_flow = pd.DataFrame(columns=list(res_cash_flow['financials'][0].keys()))
for ratio in res_cash_flow['financials']:
    df_cash_flow = df_cash_flow.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))
df_cash_flow.head()
# Out:
#                   date Depreciation & Amortization Stock-based compensation  \
# 2019-06-30  2019-06-30                2924000000.0             1190000000.0
# 2019-03-31  2019-03-31                2926000000.0             1172000000.0
# 2018-12-31  2018-12-31                2995000000.0             1183000000.0
# 2018-09-30  2018-09-30                2837000000.0             1107000000.0
# 2018-06-30  2018-06-30                2516000000.0             1012000000.0
#
#            Operating Cash Flow Capital Expenditure Acquisitions and disposals  \
# 2019-06-30       16108000000.0       -4051000000.0               -281000000.0
# 2019-03-31       13520000000.0       -2565000000.0               -269000000.0
# 2018-12-31        8900000000.0       -3707000000.0              -1593000000.0
# 2018-09-30       13657000000.0       -3602000000.0               -245000000.0
# 2018-06-30       11418000000.0       -3980000000.0               -434000000.0
#
#            Investment purchases and sales Investing Cash flow  \
# 2019-06-30                  -2925000000.0       -7257000000.0
# 2019-03-31                   1471000000.0       -1363000000.0
# 2018-12-31                   1100000000.0       -4200000000.0
# 2018-09-30                    894000000.0       -2953000000.0
# 2018-06-30                   1752000000.0       -2670000000.0
#
#            Issuance (repayment) of debt Issuance (buybacks) of shares  \
# 2019-06-30                -1000000000.0                 -4325000000.0
# 2019-03-31                          0.0                 -4479000000.0
# 2018-12-31                -3000000000.0                 -6213000000.0
# 2018-09-30                          0.0                 -3384000000.0
# 2018-06-30                 -681000000.0                 -2107000000.0
#
#            Dividend payments Financing Cash Flow  \
# 2019-06-30     -3521000000.0       -8686000000.0
# 2019-03-31     -3526000000.0       -7601000000.0
# 2018-12-31     -3544000000.0      -13216000000.0
# 2018-09-30     -3220000000.0       -7384000000.0
# 2018-06-30     -3226000000.0       -6039000000.0
#
#            Effect of forex changes on cash Net cash flow / Change in cash  \
# 2019-06-30                     -21000000.0                    144000000.0
# 2019-03-31                      18000000.0                   4574000000.0
# 2018-12-31                      17000000.0                  -8499000000.0
# 2018-09-30                    -129000000.0                   3191000000.0
# 2018-06-30                      16000000.0                   2725000000.0
#
#            Free Cash Flow Net Cash/Marketcap
# 2019-06-30  12057000000.0             0.0533
# 2019-03-31  10955000000.0             0.0575
# 2018-12-31   5193000000.0             0.0626
# 2018-09-30  10055000000.0             0.0609
# 2018-06-30   7438000000.0             0.0676

# %% [markdown]
# #### Create DataFrame for the Enterprise Values

# %%
df_enterprise_value = pd.DataFrame(columns=list(res_enterprise_value['enterpriseValues'][0].keys()))
for ratio in res_enterprise_value['enterpriseValues']:
    df_enterprise_value = df_enterprise_value.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))
df_enterprise_value.head()
# Out:
#                   date Stock Price Number of Shares  Market Capitalization  \
# 2019-03-31  2019-03-31    118.5811     7672000000.0           9.097542e+11
# 2018-12-31  2018-12-31     100.765     7692000000.0           7.750844e+11
# 2018-09-30  2018-09-30    114.2005     7673000000.0           8.762604e+11
# 2018-06-30  2018-06-30     98.4119     7682000000.0           7.560002e+11
# 2018-03-31  2018-03-31     86.7295     7698000000.0           6.676437e+11
#
#             - Cash & Cash Equivalents  + Total Debt  Enterprise Value
# 2019-03-31               1.316180e+11  7.907200e+10      8.572082e+11
# 2018-12-31               1.276620e+11  7.885200e+10      7.262744e+11
# 2018-09-30               1.358800e+11  8.188200e+10      8.222624e+11
# 2018-06-30               1.337680e+11  8.180800e+10      7.040402e+11
# 2018-03-31               1.322700e+11  8.290800e+10      6.182817e+11

# %% [markdown]
# #### Create DataFrame for Historical Discounted Cash Flow Values

# %%
df_historical_dcf = pd.DataFrame(columns=list(res_historical_dcf['historicalDCF'][0].keys()))
for ratio in res_historical_dcf['historicalDCF']:
    df_historical_dcf = df_historical_dcf.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))

df_dcf = pd.DataFrame.from_dict({res_dcf['date']: res_dcf},  orient='index')
df_historical_dcf = df_historical_dcf.append(df_dcf[['date', 'Stock Price', 'DCF']])

df_historical_dcf.head()
# Out:
#                   date  Stock Price       DCF
# 2019-03-31  2019-03-31     118.5811  118.5811
# 2018-12-31  2018-12-31     100.7650  100.7650
# 2018-09-30  2018-09-30     114.2005  114.2005
# 2018-06-30  2018-06-30      98.4119   98.4119
# 2018-03-31  2018-03-31      86.7295   86.7295

# %% [markdown]
# #### Create DataFrame for Key Metrics

# %%
df_metrics = pd.DataFrame(columns=list(res_metrics['metrics'][0].keys()))
for ratio in res_metrics['metrics']:
    df_metrics = df_metrics.append(pd.DataFrame.from_dict({ratio['date']: ratio}, orient='index'))
df_metrics.head()
# Out:
#                   date Revenue per Share Net Income per Share  \
# 2019-06-30  2019-06-30            4.4046               1.7227
# 2019-03-31  2019-03-31            3.9847               1.1482
# 2018-12-31  2018-12-31            4.2214               1.0946
# 2018-09-30  2018-09-30            3.7904                 1.15
# 2018-06-30  2018-06-30            3.9163                1.155
#
#            Operating Cash Flow per Share Free Cash Flow per Share  \
# 2019-06-30                        2.1042                    0.675
# 2019-03-31                        1.7623                     1.31
# 2018-12-31                         1.157                    0.968
# 2018-09-30                        1.7799                    1.197
# 2018-06-30                        1.4863                    0.686
#
#            Cash per Share Book Value per Share Tangible Book Value per Share  \
# 2019-06-30        17.4813               13.368                        30.931
# 2019-03-31        17.1556               12.365                        27.805
# 2018-12-31        16.5967               11.977                        27.145
# 2018-09-30        17.7088               11.204                        27.914
# 2018-06-30        17.4132               10.768                        28.002
#
#            Shareholders Equity per Share Interest Debt per Share  ...  \
# 2019-06-30                       13.3677                 10.2372  ...
# 2019-03-31                        12.365                 10.3066  ...
# 2018-12-31                       11.9771                 10.2512  ...
# 2018-09-30                       11.2038                 10.6714  ...
# 2018-06-30                       10.7678                 10.6493  ...
#
#            Graham Number Graham Net-Net Working Capital Tangible Asset Value  \
# 2019-06-30       39.2044        -0.0083  106132000000.0       236780000000.0
# 2019-03-31       35.5399        -0.0093  106026000000.0       213317000000.0
# 2018-12-31       34.2381        -0.0126  106556000000.0       208800000000.0
# 2018-09-30       24.8012        -0.0084  107918000000.0       214185000000.0
# 2018-06-30       22.8233        -0.0084  111174000000.0       215112000000.0
#
#            Net Current Asset Value Invested Capital Average Receivables  \
# 2019-06-30           -8674000000.0   111907000000.0       28002500000.0
# 2019-03-31           -8530000000.0   106910000000.0       18238500000.0
# 2018-12-31           -9857000000.0   109672000000.0       19054000000.0
# 2018-09-30           -7457000000.0   103910000000.0       15975500000.0
# 2018-06-30           -6468000000.0   104664000000.0       24456000000.0
#
#            Average Payables Average Inventory Capex per Share
# 2019-06-30     8999500000.0      2362500000.0         -0.5292
# 2019-03-31     7583500000.0      2017500000.0         -0.3343
# 2018-12-31     7719500000.0      1982000000.0         -0.4819
# 2018-09-30     7790000000.0      3412500000.0         -0.4694
# 2018-06-30     8003500000.0      2421500000.0         -0.5181
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Create DataFrame for Profile

# %%
df_profile = pd.DataFrame(columns=list(res_profile['profile'].keys()))
df_profile = df_profile.append(pd.DataFrame.from_dict({res_profile['symbol']: res_profile['profile']}, orient='index'))
df_profile.head()
# Out:
#        price      beta    volAvg            mktCap lastDiv         range  \
# MSFT  144.09  1.216475  31780446  1105602570000.00    1.84  90.28-120.98
#
#       changes changesPercentage            companyName              exchange  \
# MSFT    -0.02          (-0.01%)  Microsoft Corporation  Nasdaq Global Select
#
#                   industry                   website  \
# MSFT  Application Software  http://www.microsoft.com
#
#                                             description            ceo  \
# MSFT  Microsoft Corp is a technology company. It dev...  Satya Nadella
#
#           sector                                              image
# MSFT  Technology  https://financialmodelingprep.com/images-New-j...

# %% [markdown]
# ---
# ## 2. Export
# ---

# %% [markdown]
# #### Merge the DataFrames

# %%
dfs = [
    df_ratios, 
    df_debtratios, 
    df_cashFlowIndicatorRatios, 
    df_profitabilityIndicatorRatios, 
    df_operatingPerformanceRatios, 
    df_liquidityMeasurementRatios, 
    df_balance_sheet,
    df_cash_flow,
    df_enterprise_value,
    df_historical_dcf,
    df_metrics
]

# %%
df_agg = None
for df in dfs:
    if df_agg is None:
        df_agg = df
    else:
        df_agg = df_agg.merge(df, left_index=True, right_index=True, how='outer')
df_agg.shape
# Out:
# (42, 164)

# %%
df_agg.T
# Out:
#                                             2009-06-30     2009-09-30  \
# priceBookValueRatio                             5.3479            NaN
# priceToBookRatio                                3.3249            NaN
# priceToSalesRatio                               3.6201            NaN
# priceEarningsRatio                             14.5828            NaN
# receivablesTurnover_x                           4.7163            NaN
# priceToFreeCashFlowsRatio                      13.3574            NaN
# priceToOperatingCashFlowsRatio                 11.1124            NaN
# priceCashFlowRatio                                   0            NaN
# priceEarningsToGrowthRatio                           0            NaN
# priceSalesRatio                                      0            NaN
# dividendYield                                                     NaN
# enterpriseValueMultiple                1.5723093419113            NaN
# priceFairValue                                       0            NaN
# debtRatio                                       0.0738            NaN
# debtEquityRatio                                 0.1453            NaN
# longtermDebtToCapitalization         0.086504710881212            NaN
# totalDebtToCapitalization             0.12683206780858            NaN
# interestCoverage                                   0.0            NaN
# cashFlowToDebtRatio                    3.3130873651236            NaN
# companyEquityMultiplier                 1.968956974569            NaN
# operatingCashFlowPerShare                       2.1282            NaN
# freeCashFlowPerShare                              1.78            NaN
# cashPerShare                                    3.5156            NaN
# payoutRatio                                      0.307            NaN
# receivablesTurnover_y                           4.7163            NaN
# operatingCashFlowSalesRatio           0.32576963225354            NaN
# freeCashFlowOperatingCashFlowRatio    0.83616115984661            NaN
# cashFlowCoverageRatios                 3.3130873651236            NaN
# shortTermCoverageRatios                         9.5185            NaN
# capitalExpenditureCoverageRatios       6.1035588329593            NaN
# ...                                                ...            ...
# Enterprise Value over EBITDA                     8.303         9.3529
# EV to Operating cash flow                       9.7623         9.1141
# EV to Free cash flow                           11.6752        10.4459
# Earnings Yield                                  0.0686         0.0599
# Free Cash Flow Yield                            0.0752         0.0829
# Debt to Equity                                  0.1453         0.1455
# Debt to Assets                                  0.0738         0.0735
# Net Debt to EBITDA                             -5.3288        -5.6795
# Current ratio                                    1.823          1.816
# Interest Coverage                                  0.0            0.0
# Income Quality                                  1.2614         1.7087
# Dividend Yield                                   0.021         0.0202
# Payout Ratio                                     0.382          0.325
# SG&A to Revenue                                 0.3505         0.2733
# R&D to Revenue                                  0.1699         0.1598
# Intangibles to Total Assets                     0.1831         0.1744
# Capex to Operating Cash Flow                    0.2257         0.0712
# Capex to Revenue                                0.0662         0.0337
# Capex to Depreciation                          -1.2731        -0.6734
# Stock-based compensation to Revenue             0.0315         0.0336
# Graham Number                                  12.7679        12.6565
# Graham Net-Net                                  0.0518         0.0516
# Working Capital                          22246000000.0  23470000000.0
# Tangible Asset Value                     63626000000.0  67377000000.0
# Net Current Asset Value                  10950000000.0  11831000000.0
# Invested Capital                         10891000000.0   7884000000.0
# Average Receivables                      12390500000.0   9061000000.0
# Average Payables                          5828000000.0   5621000000.0
# Average Inventory                          851000000.0   1395000000.0
# Capex per Share                                -0.0974        -0.0488
#
#                                         2009-12-31     2010-03-31  \
# priceBookValueRatio                            NaN            NaN
# priceToBookRatio                               NaN            NaN
# priceToSalesRatio                              NaN            NaN
# priceEarningsRatio                             NaN            NaN
# receivablesTurnover_x                          NaN            NaN
# priceToFreeCashFlowsRatio                      NaN            NaN
# priceToOperatingCashFlowsRatio                 NaN            NaN
# priceCashFlowRatio                             NaN            NaN
# priceEarningsToGrowthRatio                     NaN            NaN
# priceSalesRatio                                NaN            NaN
# dividendYield                                  NaN            NaN
# enterpriseValueMultiple                        NaN            NaN
# priceFairValue                                 NaN            NaN
# debtRatio                                      NaN            NaN
# debtEquityRatio                                NaN            NaN
# longtermDebtToCapitalization                   NaN            NaN
# totalDebtToCapitalization                      NaN            NaN
# interestCoverage                               NaN            NaN
# cashFlowToDebtRatio                            NaN            NaN
# companyEquityMultiplier                        NaN            NaN
# operatingCashFlowPerShare                      NaN            NaN
# freeCashFlowPerShare                           NaN            NaN
# cashPerShare                                   NaN            NaN
# payoutRatio                                    NaN            NaN
# receivablesTurnover_y                          NaN            NaN
# operatingCashFlowSalesRatio                    NaN            NaN
# freeCashFlowOperatingCashFlowRatio             NaN            NaN
# cashFlowCoverageRatios                         NaN            NaN
# shortTermCoverageRatios                        NaN            NaN
# capitalExpenditureCoverageRatios               NaN            NaN
# ...                                            ...            ...
# Enterprise Value over EBITDA                9.8393         8.6629
# EV to Operating cash flow                  11.4752        10.0052
# EV to Free cash flow                       12.8964        11.0372
# Earnings Yield                              0.0597         0.0666
# Free Cash Flow Yield                        0.0689         0.0787
# Debt to Equity                              0.1354         0.1312
# Debt to Assets                               0.073         0.0706
# Net Debt to EBITDA                         -3.1695        -5.5793
# Current ratio                                2.041          2.063
# Interest Coverage                              0.0            0.0
# Income Quality                              0.7459         1.8455
# Dividend Yield                              0.0171         0.0178
# Payout Ratio                                 0.173          0.283
# SG&A to Revenue                             0.2524         0.3003
# R&D to Revenue                              0.1093         0.1531
# Intangibles to Total Assets                  0.167         0.1619
# Capex to Operating Cash Flow                0.0757         0.0552
# Capex to Revenue                            0.0198         0.0281
# Capex to Depreciation                      -0.6114        -0.5879
# Stock-based compensation to Revenue         0.0247         0.0322
# Graham Number                              14.3091         15.125
# Graham Net-Net                              0.0542         0.0596
# Working Capital                      26772000000.0  28094000000.0
# Tangible Asset Value                 68382000000.0  71165000000.0
# Net Current Asset Value              14674000000.0  15318000000.0
# Invested Capital                     12563000000.0  11070000000.0
# Average Receivables                  11074500000.0   9159500000.0
# Average Payables                      5042000000.0   5311500000.0
# Average Inventory                      778500000.0    579000000.0
# Capex per Share                            -0.0425        -0.0465
#
#                                             2010-06-30     2010-09-30  \
# priceBookValueRatio                             4.3424            NaN
# priceToBookRatio                                2.7633            NaN
# priceToSalesRatio                               3.2273            NaN
# priceEarningsRatio                             10.8028            NaN
# receivablesTurnover_x                           5.1627            NaN
# priceToFreeCashFlowsRatio                       9.1775            NaN
# priceToOperatingCashFlowsRatio                  8.3769            NaN
# priceCashFlowRatio                                   0            NaN
# priceEarningsToGrowthRatio                           0            NaN
# priceSalesRatio                                      0            NaN
# dividendYield                                                     NaN
# enterpriseValueMultiple                1.5071516289822            NaN
# priceFairValue                                       0            NaN
# debtRatio                                        0.069            NaN
# debtEquityRatio                                 0.1286            NaN
# longtermDebtToCapitalization         0.096627147161247            NaN
# totalDebtToCapitalization             0.11396169935142            NaN
# interestCoverage                                   0.0            NaN
# cashFlowToDebtRatio                    4.0533759892238            NaN
# companyEquityMultiplier                1.8649269085003            NaN
# operatingCashFlowPerShare                       2.7315            NaN
# freeCashFlowPerShare                            2.5072            NaN
# cashPerShare                                    4.1743            NaN
# payoutRatio                                      0.244            NaN
# receivablesTurnover_y                           5.1627            NaN
# operatingCashFlowSalesRatio           0.38526662825683            NaN
# freeCashFlowOperatingCashFlowRatio    0.91787479749097            NaN
# cashFlowCoverageRatios                 4.0533759892238            NaN
# shortTermCoverageRatios                         24.073            NaN
# capitalExpenditureCoverageRatios       12.176530096105            NaN
# ...                                                ...            ...
# Enterprise Value over EBITDA                    6.1694         5.9081
# EV to Operating cash flow                       7.0954         6.8203
# EV to Free cash flow                            7.7302         7.4174
# Earnings Yield                                  0.0926         0.0964
# Free Cash Flow Yield                            0.1096         0.1135
# Debt to Equity                                  0.1286         0.2272
# Debt to Assets                                   0.069         0.1165
# Net Debt to EBITDA                             -4.5756        -4.2287
# Current ratio                                    2.129          2.304
# Interest Coverage                                  0.0            0.0
# Income Quality                                  1.2404         1.5146
# Dividend Yield                                  0.0226         0.0212
# Payout Ratio                                      0.25          0.206
# SG&A to Revenue                                 0.2861         0.2312
# R&D to Revenue                                  0.1465         0.1356
# Intangibles to Total Assets                     0.1574          0.148
# Capex to Operating Cash Flow                    0.1353         0.0688
# Capex to Revenue                                0.0473         0.0348
# Capex to Depreciation                          -1.0557        -0.8127
# Stock-based compensation to Revenue             0.0296         0.0323
# Graham Number                                   15.936        17.0116
# Graham Net-Net                                   0.078         0.0707
# Working Capital                          29529000000.0  33724000000.0
# Tangible Asset Value                     72561000000.0  77992000000.0
# Net Current Asset Value                  15738000000.0  14983000000.0
# Invested Capital                         15565000000.0  18627000000.0
# Average Receivables                      12103000000.0   9116500000.0
# Average Payables                          4607500000.0   5692000000.0
# Average Inventory                          728500000.0   1196000000.0
# Capex per Share                                 -0.087        -0.0655
#
#                                         2010-12-31     2011-03-31  \
# priceBookValueRatio                            NaN            NaN
# priceToBookRatio                               NaN            NaN
# priceToSalesRatio                              NaN            NaN
# priceEarningsRatio                             NaN            NaN
# receivablesTurnover_x                          NaN            NaN
# priceToFreeCashFlowsRatio                      NaN            NaN
# priceToOperatingCashFlowsRatio                 NaN            NaN
# priceCashFlowRatio                             NaN            NaN
# priceEarningsToGrowthRatio                     NaN            NaN
# priceSalesRatio                                NaN            NaN
# dividendYield                                  NaN            NaN
# enterpriseValueMultiple                        NaN            NaN
# priceFairValue                                 NaN            NaN
# debtRatio                                      NaN            NaN
# debtEquityRatio                                NaN            NaN
# longtermDebtToCapitalization                   NaN            NaN
# totalDebtToCapitalization                      NaN            NaN
# interestCoverage                               NaN            NaN
# cashFlowToDebtRatio                            NaN            NaN
# companyEquityMultiplier                        NaN            NaN
# operatingCashFlowPerShare                      NaN            NaN
# freeCashFlowPerShare                           NaN            NaN
# cashPerShare                                   NaN            NaN
# payoutRatio                                    NaN            NaN
# receivablesTurnover_y                          NaN            NaN
# operatingCashFlowSalesRatio                    NaN            NaN
# freeCashFlowOperatingCashFlowRatio             NaN            NaN
# cashFlowCoverageRatios                         NaN            NaN
# shortTermCoverageRatios                        NaN            NaN
# capitalExpenditureCoverageRatios               NaN            NaN
# ...                                            ...            ...
# Enterprise Value over EBITDA                6.9389         5.7277
# EV to Operating cash flow                    8.165         6.5689
# EV to Free cash flow                        8.9482         7.2401
# Earnings Yield                              0.0856         0.1004
# Free Cash Flow Yield                         0.097         0.1134
# Debt to Equity                              0.1995         0.2229
# Debt to Assets                              0.1048         0.1195
# Net Debt to EBITDA                         -3.4477        -5.6686
# Current ratio                                2.455          2.756
# Interest Coverage                              0.0            0.0
# Income Quality                               0.631         1.6575
# Dividend Yield                              0.0197         0.0228
# Payout Ratio                                 0.205          0.258
# SG&A to Revenue                             0.2391         0.2771
# R&D to Revenue                              0.1095         0.1381
# Intangibles to Total Assets                 0.1462         0.1343
# Capex to Operating Cash Flow                0.1173         0.0759
# Capex to Revenue                            0.0246         0.0401
# Capex to Depreciation                      -0.7406        -0.9139
# Stock-based compensation to Revenue         0.0275         0.0326
# Graham Number                              17.5169        19.0845
# Graham Net-Net                              0.0664         0.0937
# Working Capital                      35372000000.0  42221000000.0
# Tangible Asset Value                 78812000000.0  86333000000.0
# Net Current Asset Value              15859000000.0  19988000000.0
# Invested Capital                     22919000000.0  24056000000.0
# Average Receivables                  12035000000.0   9585000000.0
# Average Payables                      5650000000.0   5573500000.0
# Average Inventory                      725000000.0    778500000.0
# Capex per Share                            -0.0578        -0.0781
#
#                                            2011-06-30     2011-09-30  ...  \
# priceBookValueRatio                            3.8383            NaN  ...
# priceToBookRatio                               2.2972            NaN  ...
# priceToSalesRatio                              3.1347            NaN  ...
# priceEarningsRatio                             9.5238            NaN  ...
# receivablesTurnover_x                          4.9958            NaN  ...
# priceToFreeCashFlowsRatio                       8.959            NaN  ...
# priceToOperatingCashFlowsRatio                 8.1222            NaN  ...
# priceCashFlowRatio                                  0            NaN  ...
# priceEarningsToGrowthRatio                          0            NaN  ...
# priceSalesRatio                                     0            NaN  ...
# dividendYield                                                    NaN  ...
# enterpriseValueMultiple               2.0979018711288            NaN  ...
# priceFairValue                                      0            NaN  ...
# debtRatio                                      0.1097            NaN  ...
# debtEquityRatio                                0.2088            NaN  ...
# longtermDebtToCapitalization         0.17275810097965            NaN  ...
# totalDebtToCapitalization            0.17275810097965            NaN  ...
# interestCoverage                                  0.0            NaN  ...
# cashFlowToDebtRatio                   2.2644073483768            NaN  ...
# companyEquityMultiplier               1.9043147697213            NaN  ...
# operatingCashFlowPerShare                      3.1795            NaN  ...
# freeCashFlowPerShare                            2.507            NaN  ...
# cashPerShare                                   6.2158            NaN  ...
# payoutRatio                                     0.223            NaN  ...
# receivablesTurnover_y                          4.9958            NaN  ...
# operatingCashFlowSalesRatio          0.38594283916904            NaN  ...
# freeCashFlowOperatingCashFlowRatio    0.9127583907535            NaN  ...
# cashFlowCoverageRatios                2.2644073483768            NaN  ...
# shortTermCoverageRatios                                          NaN  ...
# capitalExpenditureCoverageRatios      11.462420382166            NaN  ...
# ...                                               ...            ...  ...
# Enterprise Value over EBITDA                   5.7853         5.2693  ...
# EV to Operating cash flow                      6.6089         5.9744  ...
# EV to Free cash flow                           7.2406         6.5052  ...
# Earnings Yield                                  0.105         0.1117  ...
# Free Cash Flow Yield                           0.1124         0.1202  ...
# Debt to Equity                                 0.2088         0.2008  ...
# Debt to Assets                                 0.1097          0.111  ...
# Net Debt to EBITDA                            -5.8292        -5.6619  ...
# Current ratio                                   2.604          2.947  ...
# Interest Coverage                                 0.0            0.0  ...
# Income Quality                                 1.0116         1.4801  ...
# Dividend Yield                                 0.0235         0.0257  ...
# Payout Ratio                                    0.229          0.235  ...
# SG&A to Revenue                                0.2934         0.2339  ...
# R&D to Revenue                                 0.1378         0.1341  ...
# Intangibles to Total Assets                    0.1226         0.1263  ...
# Capex to Operating Cash Flow                    0.108         0.0513  ...
# Capex to Revenue                                0.037         0.0251  ...
# Capex to Depreciation                         -0.9318        -0.6006  ...
# Stock-based compensation to Revenue            0.0312         0.0281  ...
# Graham Number                                 20.3984        21.0396  ...
# Graham Net-Net                                 0.1063         0.1307  ...
# Working Capital                         46144000000.0  49728000000.0  ...
# Tangible Asset Value                    95379000000.0  93852000000.0  ...
# Net Current Asset Value                 23297000000.0  27247000000.0  ...
# Invested Capital                        25754000000.0  22833000000.0  ...
# Average Receivables                     14000500000.0   9899500000.0  ...
# Average Payables                         4806000000.0   4711500000.0  ...
# Average Inventory                        1056000000.0   1756000000.0  ...
# Capex per Share                               -0.0762         -0.052  ...
#
#                                             2017-06-30      2017-09-30  \
# priceBookValueRatio                             6.0638             NaN
# priceToBookRatio                                2.5934             NaN
# priceToSalesRatio                               5.5107             NaN
# priceEarningsRatio                             20.9514             NaN
# receivablesTurnover_x                           4.7446             NaN
# priceToFreeCashFlowsRatio                      17.0161             NaN
# priceToOperatingCashFlowsRatio                 13.4704             NaN
# priceCashFlowRatio                     13.044246746146             NaN
# priceEarningsToGrowthRatio             20.218096284672             NaN
# priceSalesRatio                        5.3363748558056             NaN
# dividendYield                        0.022984867646831             NaN
# enterpriseValueMultiple                18.867216220688             NaN
# priceFairValue                         5.8754210555119             NaN
# debtRatio                                       0.3658             NaN
# debtEquityRatio                                  1.044             NaN
# longtermDebtToCapitalization          0.48147863510606             NaN
# totalDebtToCapitalization             0.51075151859971             NaN
# interestCoverage                                   0.0             NaN
# cashFlowToDebtRatio                   0.43145927527685             NaN
# companyEquityMultiplier                2.8538267720126             NaN
# operatingCashFlowPerShare                       5.1003             NaN
# freeCashFlowPerShare                             3.152             NaN
# cashPerShare                                   17.1677             NaN
# payoutRatio                                      0.465             NaN
# receivablesTurnover_y                           4.7446             NaN
# operatingCashFlowSalesRatio           0.40909796936969             NaN
# freeCashFlowOperatingCashFlowRatio    0.79423899562103             NaN
# cashFlowCoverageRatios                0.43145927527685             NaN
# shortTermCoverageRatios                3.9034680367553             NaN
# capitalExpenditureCoverageRatios       4.8600073809817             NaN
# ...                                                ...             ...
# Enterprise Value over EBITDA                    12.688          13.017
# EV to Operating cash flow                      12.4221          13.056
# EV to Free cash flow                           15.6403         16.3293
# Earnings Yield                                  0.0477          0.0457
# Free Cash Flow Yield                             0.059          0.0562
# Debt to Equity                                   1.044          1.0178
# Debt to Assets                                  0.3658          0.3663
# Net Debt to EBITDA                             -4.0205         -4.5052
# Current ratio                                    2.919            3.12
# Interest Coverage                                  0.0             0.0
# Income Quality                                  1.3639          1.8917
# Dividend Yield                                  0.0222          0.0209
# Payout Ratio                                     0.375           0.459
# SG&A to Revenue                                 0.2205          0.2029
# R&D to Revenue                                  0.1372          0.1457
# Intangibles to Total Assets                     0.1807          0.1806
# Capex to Operating Cash Flow                    0.2075          0.1714
# Capex to Revenue                                0.0892          0.0869
# Capex to Depreciation                          -0.9744         -0.8531
# Stock-based compensation to Revenue             0.0357          0.0397
# Graham Number                                  29.0076         29.8716
# Graham Net-Net                                  0.0002          0.0028
# Working Capital                         106951000000.0  109416000000.0
# Tangible Asset Value                    205084000000.0  204110000000.0
# Net Current Asset Value                     95000000.0    1581000000.0
# Invested Capital                        107924000000.0  105267000000.0
# Average Receivables                      20354000000.0   12845000000.0
# Average Payables                          7291000000.0    6787500000.0
# Average Inventory                         2216000000.0    3166500000.0
# Capex per Share                                -0.2959         -0.2766
#
#                                          2017-12-31      2018-03-31  \
# priceBookValueRatio                             NaN             NaN
# priceToBookRatio                                NaN             NaN
# priceToSalesRatio                               NaN             NaN
# priceEarningsRatio                              NaN             NaN
# receivablesTurnover_x                           NaN             NaN
# priceToFreeCashFlowsRatio                       NaN             NaN
# priceToOperatingCashFlowsRatio                  NaN             NaN
# priceCashFlowRatio                              NaN             NaN
# priceEarningsToGrowthRatio                      NaN             NaN
# priceSalesRatio                                 NaN             NaN
# dividendYield                                   NaN             NaN
# enterpriseValueMultiple                         NaN             NaN
# priceFairValue                                  NaN             NaN
# debtRatio                                       NaN             NaN
# debtEquityRatio                                 NaN             NaN
# longtermDebtToCapitalization                    NaN             NaN
# totalDebtToCapitalization                       NaN             NaN
# interestCoverage                                NaN             NaN
# cashFlowToDebtRatio                             NaN             NaN
# companyEquityMultiplier                         NaN             NaN
# operatingCashFlowPerShare                       NaN             NaN
# freeCashFlowPerShare                            NaN             NaN
# cashPerShare                                    NaN             NaN
# payoutRatio                                     NaN             NaN
# receivablesTurnover_y                           NaN             NaN
# operatingCashFlowSalesRatio                     NaN             NaN
# freeCashFlowOperatingCashFlowRatio              NaN             NaN
# cashFlowCoverageRatios                          NaN             NaN
# shortTermCoverageRatios                         NaN             NaN
# capitalExpenditureCoverageRatios                NaN             NaN
# ...                                             ...             ...
# Enterprise Value over EBITDA                14.6348         14.4212
# EV to Operating cash flow                   14.6543         14.5436
# EV to Free cash flow                         18.483         18.8521
# Earnings Yield                               0.0207          0.0229
# Free Cash Flow Yield                         0.0502          0.0492
# Debt to Equity                               1.2111          1.0463
# Debt to Assets                               0.3707          0.3377
# Net Debt to EBITDA                          -4.0906         -4.3487
# Current ratio                                 2.885           3.396
# Interest Coverage                               0.0             0.0
# Income Quality                              -1.2496          1.6367
# Dividend Yield                               0.0185          0.0183
# Payout Ratio                                 -0.512           0.438
# SG&A to Revenue                              0.1961          0.2067
# R&D to Revenue                               0.1212          0.1385
# Intangibles to Total Assets                  0.1734          0.1797
# Capex to Operating Cash Flow                 0.3284          0.2415
# Capex to Revenue                             0.0894          0.1094
# Capex to Depreciation                       -1.0197         -1.0827
# Stock-based compensation to Revenue          0.0341          0.0361
# Graham Number                               20.1749         21.6825
# Graham Net-Net                              -0.0151         -0.0141
# Working Capital                      109534000000.0  110526000000.0
# Tangible Asset Value                 211614000000.0  201371000000.0
# Net Current Asset Value              -10010000000.0   -9599000000.0
# Invested Capital                     105635000000.0  105876000000.0
# Average Receivables                   16385500000.0   15045000000.0
# Average Payables                       7868000000.0    7020500000.0
# Average Inventory                      1982000000.0    2031500000.0
# Capex per Share                             -0.3354         -0.3811
#
#                                             2018-06-30      2018-09-30  \
# priceBookValueRatio                             9.2879             NaN
# priceToBookRatio                                3.5715             NaN
# priceToSalesRatio                               6.9626             NaN
# priceEarningsRatio                             46.5163             NaN
# receivablesTurnover_x                           4.5126             NaN
# priceToFreeCashFlowsRatio                      23.8769             NaN
# priceToOperatingCashFlowsRatio                 17.5097             NaN
# priceCashFlowRatio                     17.267606189044             NaN
# priceEarningsToGrowthRatio             45.728781002957             NaN
# priceSalesRatio                        6.8663612722001             NaN
# dividendYield                        0.016758347102543             NaN
# enterpriseValueMultiple                20.741406440569             NaN
# priceFairValue                         9.1609036727194             NaN
# debtRatio                                        0.316             NaN
# debtEquityRatio                                  0.989             NaN
# longtermDebtToCapitalization            0.484712947274             NaN
# totalDebtToCapitalization             0.49723447965671             NaN
# interestCoverage                                   0.0             NaN
# cashFlowToDebtRatio                   0.53642675532955             NaN
# companyEquityMultiplier                3.1292826228874             NaN
# operatingCashFlowPerShare                       5.6992             NaN
# freeCashFlowPerShare                             4.051             NaN
# cashPerShare                                   17.3725             NaN
# payoutRatio                                      0.767             NaN
# receivablesTurnover_y                           4.5126             NaN
# operatingCashFlowSalesRatio           0.39764407393983             NaN
# freeCashFlowOperatingCashFlowRatio    0.73493756266521             NaN
# cashFlowCoverageRatios                0.53642675532955             NaN
# shortTermCoverageRatios                10.976488244122             NaN
# capitalExpenditureCoverageRatios       3.7726960110041             NaN
# ...                                                ...             ...
# Enterprise Value over EBITDA                   15.3298         16.8835
# EV to Operating cash flow                      16.3257         18.4591
# EV to Free cash flow                           22.2137         26.0172
# Earnings Yield                                  0.0215          0.0211
# Free Cash Flow Yield                             0.042          0.0361
# Debt to Equity                                   0.989          0.9525
# Debt to Assets                                   0.316          0.3178
# Net Debt to EBITDA                             -3.9376         -4.1352
# Current ratio                                    2.901           2.918
# Interest Coverage                                  0.0             0.0
# Income Quality                                  1.2868          1.5477
# Dividend Yield                                  0.0165          0.0145
# Payout Ratio                                     0.365           0.365
# SG&A to Revenue                                 0.2005          0.1804
# R&D to Revenue                                  0.1307          0.1367
# Intangibles to Total Assets                      0.169          0.1686
# Capex to Operating Cash Flow                    0.3486          0.2637
# Capex to Revenue                                0.1323          0.1238
# Capex to Depreciation                          -1.5819         -1.2697
# Stock-based compensation to Revenue             0.0336          0.0381
# Graham Number                                  22.8233         24.8012
# Graham Net-Net                                 -0.0084         -0.0084
# Working Capital                         111174000000.0  107918000000.0
# Tangible Asset Value                    215112000000.0  214185000000.0
# Net Current Asset Value                  -6468000000.0   -7457000000.0
# Invested Capital                        104664000000.0  103910000000.0
# Average Receivables                      24456000000.0   15975500000.0
# Average Payables                          8003500000.0    7790000000.0
# Average Inventory                         2421500000.0    3412500000.0
# Capex per Share                                -0.5181         -0.4694
#
#                                          2018-12-31      2019-03-31  \
# priceBookValueRatio                             NaN             NaN
# priceToBookRatio                                NaN             NaN
# priceToSalesRatio                               NaN             NaN
# priceEarningsRatio                              NaN             NaN
# receivablesTurnover_x                           NaN             NaN
# priceToFreeCashFlowsRatio                       NaN             NaN
# priceToOperatingCashFlowsRatio                  NaN             NaN
# priceCashFlowRatio                              NaN             NaN
# priceEarningsToGrowthRatio                      NaN             NaN
# priceSalesRatio                                 NaN             NaN
# dividendYield                                   NaN             NaN
# enterpriseValueMultiple                         NaN             NaN
# priceFairValue                                  NaN             NaN
# debtRatio                                       NaN             NaN
# debtEquityRatio                                 NaN             NaN
# longtermDebtToCapitalization                    NaN             NaN
# totalDebtToCapitalization                       NaN             NaN
# interestCoverage                                NaN             NaN
# cashFlowToDebtRatio                             NaN             NaN
# companyEquityMultiplier                         NaN             NaN
# operatingCashFlowPerShare                       NaN             NaN
# freeCashFlowPerShare                            NaN             NaN
# cashPerShare                                    NaN             NaN
# payoutRatio                                     NaN             NaN
# receivablesTurnover_y                           NaN             NaN
# operatingCashFlowSalesRatio                     NaN             NaN
# freeCashFlowOperatingCashFlowRatio              NaN             NaN
# cashFlowCoverageRatios                          NaN             NaN
# shortTermCoverageRatios                         NaN             NaN
# capitalExpenditureCoverageRatios                NaN             NaN
# ...                                             ...             ...
# Enterprise Value over EBITDA                14.3349         16.2237
# EV to Operating cash flow                   15.8449         18.1198
# EV to Free cash flow                        22.9089         25.5819
# Earnings Yield                               0.0428          0.0381
# Free Cash Flow Yield                         0.0409          0.0368
# Debt to Equity                               0.8559          0.8335
# Debt to Assets                               0.3046          0.3003
# Net Debt to EBITDA                           -3.648         -3.9178
# Current ratio                                 3.118           2.969
# Interest Coverage                               0.0             0.0
# Income Quality                                1.057          1.5348
# Dividend Yield                               0.0169          0.0148
# Payout Ratio                                  0.422             0.4
# SG&A to Revenue                              0.1762          0.1879
# R&D to Revenue                               0.1253          0.1412
# Intangibles to Total Assets                  0.1934          0.1898
# Capex to Operating Cash Flow                 0.4165          0.1897
# Capex to Revenue                             0.1142          0.0839
# Capex to Depreciation                       -1.2377         -0.8766
# Stock-based compensation to Revenue          0.0364          0.0383
# Graham Number                               34.2381         35.5399
# Graham Net-Net                              -0.0126         -0.0093
# Working Capital                      106556000000.0  106026000000.0
# Tangible Asset Value                 208800000000.0  213317000000.0
# Net Current Asset Value               -9857000000.0   -8530000000.0
# Invested Capital                     109672000000.0  106910000000.0
# Average Receivables                   19054000000.0   18238500000.0
# Average Payables                       7719500000.0    7583500000.0
# Average Inventory                      1982000000.0    2017500000.0
# Capex per Share                             -0.4819         -0.3343
#
#                                            2019-06-30 2019-10-28
# priceBookValueRatio                           10.1498        NaN
# priceToBookRatio                               4.3865        NaN
# priceToSalesRatio                              8.2618        NaN
# priceEarningsRatio                            26.5519        NaN
# receivablesTurnover_x                           4.494        NaN
# priceToFreeCashFlowsRatio                     27.2105        NaN
# priceToOperatingCashFlowsRatio                19.9232        NaN
# priceCashFlowRatio                                  0        NaN
# priceEarningsToGrowthRatio                          0        NaN
# priceSalesRatio                                     0        NaN
# dividendYield                                                NaN
# enterpriseValueMultiple               3.7325085786527        NaN
# priceFairValue                                      0        NaN
# debtRatio                                      0.2735        NaN
# debtEquityRatio                                0.7658        NaN
# longtermDebtToCapitalization         0.41585797465464        NaN
# totalDebtToCapitalization            0.43368973303228        NaN
# interestCoverage                                  0.0        NaN
# cashFlowToDebtRatio                  0.66591378914325        NaN
# companyEquityMultiplier               2.8003127137692        NaN
# operatingCashFlowPerShare                      6.8011        NaN
# freeCashFlowPerShare                            4.189        NaN
# cashPerShare                                  17.4402        NaN
# payoutRatio                                     0.352        NaN
# receivablesTurnover_y                           4.494        NaN
# operatingCashFlowSalesRatio          0.41468337531686        NaN
# freeCashFlowOperatingCashFlowRatio    0.7331608699818        NaN
# cashFlowCoverageRatios               0.66591378914325        NaN
# shortTermCoverageRatios               9.4606598984772        NaN
# capitalExpenditureCoverageRatios      3.7475763016158        NaN
# ...                                               ...        ...
# Enterprise Value over EBITDA                  17.7757        NaN
# EV to Operating cash flow                     18.8606        NaN
# EV to Free cash flow                           25.725        NaN
# Earnings Yield                                 0.0377        NaN
# Free Cash Flow Yield                           0.0368        NaN
# Debt to Equity                                 0.7658        NaN
# Debt to Assets                                 0.2735        NaN
# Net Debt to EBITDA                             -3.573        NaN
# Current ratio                                   2.529        NaN
# Interest Coverage                                 0.0        NaN
# Income Quality                                 1.2215        NaN
# Dividend Yield                                 0.0133        NaN
# Payout Ratio                                    0.267        NaN
# SG&A to Revenue                                0.1894        NaN
# R&D to Revenue                                 0.1338        NaN
# Intangibles to Total Assets                    0.1737        NaN
# Capex to Operating Cash Flow                   0.2515        NaN
# Capex to Revenue                               0.1201        NaN
# Capex to Depreciation                         -1.3854        NaN
# Stock-based compensation to Revenue            0.0353        NaN
# Graham Number                                 39.2044        NaN
# Graham Net-Net                                -0.0083        NaN
# Working Capital                        106132000000.0        NaN
# Tangible Asset Value                   236780000000.0        NaN
# Net Current Asset Value                 -8674000000.0        NaN
# Invested Capital                       111907000000.0        NaN
# Average Receivables                     28002500000.0        NaN
# Average Payables                         8999500000.0        NaN
# Average Inventory                        2362500000.0        NaN
# Capex per Share                               -0.5292        NaN
#
# [164 rows x 42 columns]

# %%
df_profile.reset_index().to_csv('../data/raw/' + '.'.join(tickers) + '.profile.csv')

# %%
df_agg.reset_index().to_csv('../data/raw/' + '.'.join(tickers) + '.csv')
